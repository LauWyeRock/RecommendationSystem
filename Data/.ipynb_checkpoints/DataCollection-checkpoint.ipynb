# %%
import requests
from dotenv import load_dotenv
import os
import json
import base64   
import pandas as pd
import librosa
import numpy as np
import lyricsgenius
import langdetect
import re
import string
import tempfile



# Dataset (uncleaned user w song)  
# users - top - liked
# 10k users - 100k unique songs?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# For any api we can try using the "+" email trick to get more API keys

spotify_client_id = "dae4aecab9ff4dfeb227cb9ff279ebf3"
spotify_client_secret = "0120d846e45e44c4843a8f983eeeb4a2"

genius_client_id = "wZZ2RWc5mqp-5Pbz2W1rQJWE8LQ3pFBrb1Hw5_AOqgybq28mt7kjdjcG4zktCNbO"
genius_client_secret = "PefqBJHor_muDgTutGlaXXaxmzsI7TQCps9FQ3FwkUTT0WJIT3s0A5YA9mnFbfp_-CBhQF7b0omgE8kaM3dJ3w"
genius_access_token = "NUHHVpwnmbDYUYw8Padu0gQeHvYN4OsKYtE2MKNUpBUI6yR-xZXKY6S5NvCnFbiP"

lastfm_api_key = "97d5a64d5ba4a8bc580b752ceff3b87f"
lastfm_secret = "35175090bd61f6f16ac607bd26e5b1de"

aud_api = "d3e2b670a1feab78763ef53399364109" ## Valid until 4 march

# %% [markdown]
# Deezer API to get 30 seconds preview of songs

# %%
def search_deezer_track(track_name):
    search_url = "https://api.deezer.com/search/track"
    params = {"q": track_name}
    response = requests.get(search_url, params=params)
    
    if response.status_code == 200:
        tracks = response.json().get('data', [])
        for track in tracks:
            print(f"Track ID: {track['id']}, Title: {track['title']}, Artist: {track['artist']['name']}")
    else:
        print(f"Failed to search tracks. Status code: {response.status_code}")


def get_deezer_track_info(track_id):
    """
    Fetch track information and MP3 preview file URL from Deezer API.

    Parameters:
    - track_id: The unique identifier for the track on Deezer.

    Returns:
    A dictionary with track information and the preview URL.
    """
    base_url = "https://api.deezer.com/track/"
    response = requests.get(f"{base_url}{track_id}")
    
    if response.status_code == 200:
        data = response.json()
        main_artist = data.get("artist", {}).get("name", "")
        contributors = [contributor['name'] for contributor in data.get("contributors", []) if contributor['name'] != main_artist]
        featured_artists = ", ".join(contributors) if contributors else None

        track_info = {
            "title": data.get("title"),
            "artist": main_artist,
            "featured_artists": featured_artists,
            "duration": data.get("duration"),
            "album": data.get("album", {}).get("title"),
            "preview_url": data.get("preview"),
            "link": data.get("link")
        }
        return track_info
    else:
        print(f"Failed to fetch data for track ID {track_id}. Status code: {response.status_code}")
        return {}


def get_song_details_from_url(audio_url, api_token):
    """
    Fetch song details using AudD API from an audio URL.

    Parameters:
    - audio_url: URL to the audio file for song recognition.
    - api_token: Your AudD API token.

    Returns:
    A dictionary with song details.
    """
    api_endpoint = "https://api.audd.io/"
    params = {
        "url": audio_url,
        "return": "apple_music,spotify",  # You can specify what additional data you want (e.g., metadata from Apple Music or Spotify)
        "api_token": api_token,
    }

    response = requests.post(api_endpoint, data=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch song details. Status code: {response.status_code}")
        return {}



# audio_url = "https://cdns-preview-c.dzcdn.net/stream/c-cabe5eee524ba4c4708032cdc0bbe7fe-4.mp3"  # Replace with the actual URL to the audio file
# song_details = get_song_details_from_url(audio_url, aud_api)
# print(json.dumps(song_details, indent=4))

get_deezer_track_info("811112942")
# Out:
# {'title': 'Blueming',
#  'artist': 'IU',
#  'featured_artists': None,
#  'duration': 217,
#  'album': 'Love poem',
#  'preview_url': 'https://cdns-preview-c.dzcdn.net/stream/c-cabe5eee524ba4c4708032cdc0bbe7fe-4.mp3',
#  'link': 'https://www.deezer.com/track/811112942'}

# %% [markdown]
# LastFM API to get Song info

# %%
base_url = 'http://ws.audioscrobbler.com/2.0/'

def lastfm_get(payload):
    headers = {'user-agent': 'DataCollectorBot'}
    payload['api_key'] = lastfm_api_key
    payload['format'] = 'json'
    response = requests.get(base_url, headers=headers, params=payload)
    return response.json()

def get_song_details(artist_name, track_name):
    payload = {
        'method': 'track.getInfo',
        'artist': artist_name,
        'track': track_name,
    }
    json_response = lastfm_get(payload)
    return json_response.get('track', {})

def get_artist_details(artist_name):
    payload = {
        'method': 'artist.getInfo',
        'artist': artist_name,
    }
    json_response = lastfm_get(payload)
    return json_response.get('artist', {})

def get_recommendations(artist_name, track_name, limit=20):
    payload = {
        'method': 'track.getSimilar',
        'artist': artist_name,
        'track': track_name,
        'limit': limit,
    }
    json_response = lastfm_get(payload)
    return json_response.get('similartracks', {}).get('track', [])

# %% [markdown]
# LastFM API to get top / trending tracks (Global and by country)

# %%
def get_global_top_tracks(limit=50):
    payload = {
        'method': 'chart.getTopTracks',
        'limit': limit,
    }
    json_response = lastfm_get(payload)
    return json_response.get('tracks', {}).get('track', [])

def get_top_tracks_by_country(country, limit=50):
    payload = {
        'method': 'geo.getTopTracks',
        'country': country,
        'limit': limit,
    }
    json_response = lastfm_get(payload)
    return json_response.get('tracks', {}).get('track', [])

# %% [markdown]
# Spotify API

# %%
def get_token():
    auth_string = spotify_client_id + ":" + spotify_client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization" : "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}
    result = requests.post(url,headers=headers, data=data)
    json_result= json.loads(result.content)
    token = json_result['access_token']
    return token

def get_auth_header(token):
    return {"Authorization": "Bearer " + token }


def get_song_details(song_id, auth_header):
    """Fetch song metadata using Spotify API."""
    url = f"https://api.spotify.com/v1/tracks/{song_id}"
    response = requests.get(url, headers=auth_header)
    return response.json()

def get_audio_features(song_id, auth_header):
    """Fetch audio features for a song."""
    url = f"https://api.spotify.com/v1/audio-features/{song_id}"
    response = requests.get(url, headers=auth_header)
    return response.json()

def get_audio_analysis(song_id, auth_header):
    """Fetch detailed audio analysis for a song."""
    url = f"https://api.spotify.com/v1/audio-analysis/{song_id}"
    response = requests.get(url, headers=auth_header)
    return response.json()


def get_artist_details(artist_id, auth_header):
    """Fetch artist metadata including popularity."""
    url = f"https://api.spotify.com/v1/artists/{artist_id}"
    response = requests.get(url, headers=auth_header)
    return response.json()

def download_song_preview(preview_url, song_id):
    if not preview_url:
        print(f"No preview available for song ID {song_id}")
        return None
    response = requests.get(preview_url)
    if response.status_code == 200:
        file_path = f"previews/{song_id}.mp3"
        with open(file_path, 'wb') as file:
            file.write(response.content)
        return file_path
    else:
        print(f"Failed to download preview for song ID {song_id}")
        return None

## the seeds must be their ids
def get_recommendations(token, seed_artists=None, seed_genres=None, seed_tracks=None):
    url = "https://api.spotify.com/v1/recommendations"
    headers = get_auth_header(token)
    params = {
        "limit": 20  # You can adjust this to fetch more or fewer tracks
    }
    if seed_artists:
        params["seed_artists"] = ','.join(seed_artists)
    if seed_genres:
        params["seed_genres"] = ','.join(seed_genres)
    if seed_tracks:
        params["seed_tracks"] = ','.join(seed_tracks)
    
    result = requests.get(url, headers=headers, params=params)
    
    try:
        result.raise_for_status()
        json_result = result.json()
        return json_result['tracks']
    except json.JSONDecodeError:
        print(f"Error decoding JSON response: {result.content}")
        return None
    except requests.exceptions.HTTPError as err:
        print(f"HTTP error: {err}")
        return None

# %%
def get_spotify_token():
    auth_string = spotify_client_id + ":" + spotify_client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization" : "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}
    result = requests.post(url, headers=headers, data=data)
    json_result = json.loads(result.content)
    token = json_result['access_token']
    return token

def search_song(song_name, artist_name, token):
    query = f"{song_name} artist:{artist_name}"
    url = "https://api.spotify.com/v1/search"
    headers = get_auth_header(token)
    params = {
        "q": query,
        "type": "track",
        "limit": 1
    }
    response = requests.get(url, headers=headers, params=params).json()
    tracks = response.get('tracks', {}).get('items', [])
    return tracks[0]['id'] if tracks else None

def get_song_audio_features(song_name, artist_name):
    token = get_spotify_token()
    song_id = search_song(song_name, artist_name, token)
    if not song_id:
        print(f"Song '{song_name}' by '{artist_name}' not found.")
        return None
    auth_header = get_auth_header(token)
    audio_features = get_audio_features(song_id, auth_header)
    return audio_features

# Example usage
song_name = "Blueming"
artist_name = "IU"
audio_features = get_song_audio_features(song_name, artist_name)
print(audio_features)
# Out:
# {'danceability': 0.819, 'energy': 0.674, 'key': 0, 'loudness': -3.145, 'mode': 1, 'speechiness': 0.0587, 'acousticness': 0.0849, 'instrumentalness': 0, 'liveness': 0.0667, 'valence': 0.682, 'tempo': 106.032, 'type': 'audio_features', 'id': '4Dr2hJ3EnVh2Aaot6fRwDO', 'uri': 'spotify:track:4Dr2hJ3EnVh2Aaot6fRwDO', 'track_href': 'https://api.spotify.com/v1/tracks/4Dr2hJ3EnVh2Aaot6fRwDO', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Dr2hJ3EnVh2Aaot6fRwDO', 'duration_ms': 217053, 'time_signature': 4}

# %% [markdown]
# Spotify Trending Artists and Songs

# %%
# Today's Top Hits: 37i9dQZF1DXcBWIGoYBM5M
# Global Top 50: 37i9dQZEVXbMDoHDwVN2tF
# United States Top 50: 37i9dQZEVXbLRQDuF5jeBp
# Viral Hits: 37i9dQZF1DX2L0iB23Enbq

def get_top_artists_from_playlist(playlist_id):
    url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"
    headers = get_auth_header(get_token())
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        tracks_data = response.json()
        artists = []
        for item in tracks_data['items']:
            track_artists = item['track']['artists']
            for artist in track_artists:
                artists.append({
                    "name": artist['name'],
                    "id": artist['id']
                })
        return artists
    else:
        return "Failed to fetch data from Spotify."

def get_featured_playlists(country=None):
    url = "https://api.spotify.com/v1/browse/featured-playlists"
    headers = get_auth_header(get_token())
    params = {"country": country} if country else {}
    response = requests.get(url, headers=headers, params=params)
    return response.json() 

def get_top_tracks_from_playlists(playlist_id):
    url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"
    headers = get_auth_header(get_token())
    response = requests.get(url, headers=headers)
    return response.json() 

featured_playlists_global = get_featured_playlists()
featured_playlists_country = get_featured_playlists(country="US")  

playlist_id = "37i9dQZF1DXcBWIGoYBM5M"
top_tracks = get_top_tracks_from_playlists(playlist_id)
top_artists = get_top_artists_from_playlist(playlist_id)

# print(json.dumps(featured_playlists_global, indent=2))
# # print(json.dumps(top_tracks, indent=2))
# for artist in top_artists:
#     print(artist['name'], artist['id'])

# %% [markdown]
# Danceability: tempo, chroma_stft
#
# Energy: rms, spectral_centroid
#
# Instrumentalness: mfcc (Higher variance in MFCCs might indicate instrumental tracks)
#
# Loudness: rms
#
# Speechiness: zcr, mfcc (Patterns in MFCCs that indicate speech)
#
# Valence, Mood, Emotion: These are subjective and would require complex modeling with labeled data to infer accurately from the extracted features. Machine learning models trained on datasets where songs
# are labeled with these attributes can use these features as input to predict mood

# %% [markdown]
# Librosa API for low level audio analysis

# %%
def extract_librosa_features_from_url(url):
    # Fetch the audio file from the URL
    response = requests.get(url)
    if response.status_code != 200:
        raise Exception(f"Failed to download audio file from {url}")
    
    # Create a temporary file and manually manage it
    temp_dir = tempfile.gettempdir()
    temp_file = tempfile.NamedTemporaryFile(delete=False, suffix=".mp3", dir=temp_dir)
    temp_file_path = temp_file.name
    
    try:
        # Write the fetched content to the temp file and close it to release the lock
        temp_file.write(response.content)
        temp_file.close()
        
        # Now, load the audio file from the path
        y, sr = librosa.load(temp_file_path, sr=None)  # Using sr=None to preserve the original sampling rate
        
        # Analyze the audio file
        tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)
        rms = np.mean(librosa.feature.rms(y=y))
        spectral_centroid = np.mean(librosa.feature.spectral_centroid(y=y, sr=sr))
        zcr = np.mean(librosa.feature.zero_crossing_rate(y))
        beat_times = librosa.frames_to_time(beat_frames, sr=sr)
        
        features = {
            'mfcc': np.mean(librosa.feature.mfcc(y=y, sr=sr).T, axis=0),
            'chroma': np.mean(librosa.feature.chroma_stft(y=y, sr=sr).T, axis=0),
            'rms': rms,
            'spectral_centroid': spectral_centroid,
            'zcr': zcr,
            'tempo': tempo,
            'beat_times': beat_times
        }
    finally:
        # Ensure the temporary file is removed after processing
        os.remove(temp_file_path)

    return features

# Example usage
url = 'https://cdns-preview-c.dzcdn.net/stream/c-cabe5eee524ba4c4708032cdc0bbe7fe-4.mp3'
features = extract_librosa_features_from_url(url)
print(features)
# Out:
# {'mfcc': array([-29.733725 , 119.54214  , -39.87224  ,  39.308147 , -26.230635 ,
#         38.345    , -18.36275  ,  23.204859 , -11.205817 ,   7.416219 ,
#         -7.5335813,   6.9686804,  -7.1242647,   8.670854 ,   2.2209277,
#          3.7230785,   7.3588877,  -2.9295928,   4.087896 , -12.117584 ],
#       dtype=float32), 'chroma': array([0.5833566 , 0.41872796, 0.45743138, 0.42218533, 0.35972908,
#        0.2739078 , 0.28585538, 0.43279177, 0.332491  , 0.31129304,
#        0.3100566 , 0.42006618], dtype=float32), 'rms': 0.31068033, 'spectral_centroid': 3933.916709897445, 'zcr': 0.09486810132038927, 'tempo': 105.46875, 'beat_times': array([ 0.05804989,  0.74303855,  1.31192744,  1.88081633,  2.43809524,
#         2.99537415,  3.57587302,  4.13315193,  4.70204082,  5.24770975,
#         5.83981859,  6.40870748,  6.97759637,  7.53487528,  8.10376417,
#         8.67265306,  9.22993197,  9.79882086, 10.36770975, 10.93659864,
#        11.50548753, 12.06276644, 12.63165533, 13.20054422, 13.76943311,
#        14.32671202, 14.89560091, 15.4644898 , 16.03337868, 16.5906576 ,
#        17.15954649, 17.7168254 , 18.29732426, 18.85460317, 19.42349206,
#        19.98077098, 20.54965986, 21.11854875, 21.68743764, 22.24471655,
#        22.81360544, 23.38249433, 23.95138322, 24.52027211, 25.089161  ,
#        25.64643991, 26.2153288 , 26.78421769, 27.35310658, 27.91038549,
#        28.47927438, 29.04816327, 29.60544218])}

# %% [markdown]
# Genius API to get song lyrics

# %%
def fetch_and_clean_lyrics(artist_name, song_name):
    # Normalize the song and artist names by removing common noise
    song_name_clean = re.sub(r"[\(].*?[\)]", "", song_name).split(' - ', 1)[0]
    artist_name_clean = re.sub(r"[\(].*?[\)]", "", artist_name)
    
    # Remove punctuation for better matching
    song_name_clean = song_name_clean.translate(str.maketrans('', '', string.punctuation))
    artist_name_clean = artist_name_clean.translate(str.maketrans('', '', string.punctuation))

    genius = lyricsgenius.Genius(genius_access_token, timeout=15)
    try:
        # Attempt to fetch the song lyrics
        song = genius.search_song(song_name_clean, artist_name_clean)
        if song and song.lyrics:
            lyrics = song.lyrics
            # Clean lyrics by removing sections like [Chorus] and any excess whitespace
            lyrics_cleaned = re.sub("[\(\[].*?[\)\]]", "", lyrics).replace("\n", " ").strip()
            return lyrics_cleaned.lower()  # Convert to lowercase
    except Exception as e:
        print(f"An error occurred while fetching lyrics for {song_name}: {e}")
    
    return "Lyrics not found"

# %% [markdown]
# MusicBrainz API to get more song info

# %%
import musicbrainzngs

musicbrainzngs.set_useragent("YourAppName", "0.1", "YourContactInfo")  # Replace with your app's actual details


def get_musicbrainz_artist_details(artist_name):
    """
    Fetch artist details from MusicBrainz, including popularity (using score) and genres.
    """
    result = musicbrainzngs.search_artists(artist=artist_name, limit=1)
    if result['artist-list']:
        artist = result['artist-list'][0]
        # Popularity can be inferred from the 'score' field, though it's not a direct measure like Spotify's popularity index
        popularity = artist.get('score')
        # Genre information might be available in the 'tag-list' field
        genres = [tag['name'] for tag in artist.get('tag-list', []) if int(tag.get('count', 0)) > 0]
        return {'popularity': popularity, 'genres': genres}
    return {}

def get_musicbrainz_track_release_date(track_id):
    """
    Fetch the release date of a track using MusicBrainz. Track ID here refers to MusicBrainz's recording ID.
    """
    result = musicbrainzngs.get_recording_by_id(track_id, includes=["releases"])
    if 'recording' in result and 'release-list' in result['recording'] and result['recording']['release-list']:
        release_date = result['recording']['release-list'][0].get('date')
        return release_date
    return None


def get_production_details(mbid):
    """
    Fetch production details including producers and songwriters for a given MusicBrainz ID (MBID)
    """
    try:
        result = musicbrainzngs.get_recording_by_id(mbid, includes=["artist-rels", "work-rels"])
        recording = result["recording"]
        details = {"producers": [], "songwriters": []}

        if "work-rels" in recording:
            for work_rel in recording["work-rels"]:
                if work_rel["type"] == "writer":
                    details["songwriters"].append(work_rel["work"]["title"])

        if "artist-rels" in recording:
            for artist_rel in recording["artist-rels"]:
                if artist_rel["type"] == "producer":
                    details["producers"].append(artist_rel["artist"]["name"])

        return details
    except musicbrainzngs.WebServiceError as exc:
        print(f"MusicBrainz API error: {exc}")
    except Exception as e:
        print(f"Failed to fetch production details: {e}")
    return {}

# Example MBID
mbid = "1ff57329-7bf3-4ceb-9c0f-1e3acee5b832"
production_details = get_production_details(mbid)
print(production_details)
# Out:
# MusicBrainz API error: caused by: HTTP Error 404: Not Found
# {}

# %% [markdown]
# Main function for song info (Non spotify)

# %%
def combine_song_data(song_ids):
    # Placeholder for the token retrieval and authentication methods
    # Since the actual implementation depends on the specific API being used
    # You would replace this with Deezer authentication if necessary
    token = "YOUR_DEEZER_TOKEN_HERE"  # Placeholder token

    songs_data = []
    for song_id in song_ids:
        # Get track details from Deezer
        track_info = get_deezer_track_info(song_id)

        # Since Deezer does not provide all the desired audio features directly,
        # we need to use `librosa` for analyzing the audio and extracting features
        preview_url = track_info.get("preview_url")
        if preview_url:
            librosa_features = extract_librosa_features_from_url(preview_url)
        else:
            librosa_features = {}

        # Lyrics and language detection
        artist_name = track_info["artist"]
        song_name = track_info["title"]
        lyrics = fetch_and_clean_lyrics(artist_name, song_name)
        language = langdetect.detect_langs(lyrics) if lyrics != "Lyrics not found" else None
        # language detection here depends on the actual content and method used for detection
        
        # Combining data into a dictionary
        song_data = {
            "song_id": song_id,
            "song_title": track_info.get("title"),
            "song_album": track_info.get("album"),
            "artist": track_info.get("artist"),
            "featured_artists": track_info.get("featured_artists"),
            "duration": track_info.get("duration"),
            # "genre": Not directly provided; might use LastFM or manual mapping
            # "available_markets", "release_date", "artist_popularity": Not available from Deezer directly
            "preview_path": preview_url,
            "lyrics": lyrics,
            'language': language,
            **librosa_features  # This unpacks the mfcc, chroma, beat_times directly into the dictionary
        }
        
        # Additional details like genre, popularity, etc., would need to be fetched from other APIs or manually filled
        songs_data.append(song_data)
    
    # Creating a DataFrame from the combined data
    df = pd.DataFrame(songs_data)
    return df


# Example song IDs for Deezer; replace these with actual Deezer track IDs you want to analyze
song_ids = ["1109731"]  # Example Deezer track IDs
df = combine_song_data(song_ids)
print(df)
# Out:
# Searching for "Lose Yourself" by Eminem...
# Done.
#    song_id     song_title              song_album  artist featured_artists  \
# 0  1109731  Lose Yourself  Curtain Call: The Hits  Eminem             None
#
#    duration                                       preview_path  \
# 0       326  https://cdns-preview-1.dzcdn.net/stream/c-1303...
#
#                                               lyrics                 language  \
# 0  771 contributorstranslationsdeutschtürkçefranç...  [en:0.9999956617793786]
#
#                                                 mfcc  \
# 0  [-128.5885, 140.22298, -42.04305, 33.49153, 7....
#
#                                               chroma       tempo  \
# 0  [0.5176217, 0.5379118, 0.6332326, 0.5261811, 0...  172.265625
#
#                                           beat_times
# 0  [0.058049886621315196, 0.3831292517006803, 0.7...

# %% [markdown]
# Main Function for Song Info (Spotify)

# %%
def combine_song_data(song_ids):
    
    token = get_token()
    auth_header = get_auth_header(token)
    
    songs_data = []
    for song_id in song_ids:
        song_details = get_song_details(song_id, auth_header)
        audio_features = get_audio_features(song_id, auth_header)
        preview_url = song_details.get("preview_url")
        preview_path = download_song_preview(preview_url, song_id) if preview_url else None

        # Fetch artist details for the first artist
        artist_details = get_artist_details(song_details["artists"][0]["id"], auth_header) if song_details["artists"] else {}

        artist_name = song_details["artists"][0]["name"] if song_details["artists"] else ""
        song_name = song_details.get("name", "")
        featured_artists = ", ".join([artist['name'] for artist in song_details['artists'][1:]]) if len(song_details['artists']) > 1 else None
        lyrics = fetch_and_clean_lyrics(artist_name, song_name)
        language = langdetect.detect_langs(lyrics) if lyrics != "Lyrics not found" else None
        librosa_features = extract_librosa_features(preview_path) if preview_path else {}

        combined_data = {
            "song_id": song_id,
            "name": song_details.get("name"),
            "album": song_details["album"]["name"] if song_details.get("album") else None,
            "artist": song_details["artists"][0]["name"] if song_details["artists"] else None,
            "featured_artists": featured_artists,
            "genre": artist_details.get("genres")[0] if artist_details.get("genres") else None,
            "available_markets": len(song_details["available_markets"]) if song_details.get("available_markets") else 0,
            "release_date": song_details["album"]["release_date"] if song_details.get("album") else None,
            "artist_popularity": artist_details.get("popularity"),
            "duration_ms": song_details.get("duration_ms"),
            "danceability": audio_features.get("danceability"),
            "energy": audio_features.get("energy"),
            "instrumentalness": audio_features.get("instrumentalness"),
            "loudness": audio_features.get("loudness"),
            "speechiness": audio_features.get("speechiness"),
            "tempo": audio_features.get("tempo"),
            "time_signature": audio_features.get("time_signature"),
            "valence": audio_features.get("valence"),
            "preview_path": preview_path,
            "lyrics": lyrics,
            "language": language,
            **librosa_features
        }
        songs_data.append(combined_data)
    
    df = pd.DataFrame(songs_data)
    return df

# Example usage with dummy song IDs
# song_ids = ["3n3Ppam7vgaVa1iaRUc9Lp", "0VjIjW4GlUZAMYd2vXMi3b", '7qiZfU4dY1lWllzX7mPBI3', '2XU0oxnq2qxCpomAAuJY8K', '7qEHsqek33rTcFNT9PFqLf',
#             '2Fxmhks0bxGSBdJ92vM42m', '6v3KW9xbzN5yKLt9YKDYA2', '3KkXRkHbMCARz0aVfEt68P', '21jGcNKet2qwijlDFuPiPb', 
#             '2b8fOow8UzyDFAE27YhOZM', '3PfIrDoz19wz7qK7tYeu62']  # Replace with actual song IDs
# df = combine_song_data(song_ids)
# df

# %%
def fetch_songwriter_producer_musicbrainz(artist_name, song_name):
    base_url = "http://musicbrainz.org/ws/2/recording/"
    params = {
        "query": f'recording:"{song_name}" AND artist:"{artist_name}"',
        "fmt": "json",
        "inc": "artist-rels work-rels"
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("Failed to fetch data from MusicBrainz")
        return {}
    
def parse_songwriter_producer(data):
    songwriters = []
    producers = []
    works = []

    if 'recordings' in data:
        for recording in data['recordings']:
            if 'relations' in recording:
                # Fetching work relations
                for relation in recording['relations']:
                    if relation['type'] == 'work':
                        works.append(relation['work']['id'])
    
    # Now we have work IDs, we can fetch details for each work
    for work_id in works:
        work_data = fetch_work_details(work_id)
        if 'relations' in work_data:
            for relation in work_data['relations']:
                if relation['type'] == 'lyricist' or relation['type'] == 'composer':
                    songwriters.append(relation['artist']['name'])
                if relation['type'] == 'producer':
                    producers.append(relation['artist']['name'])
    
    return songwriters, producers

def fetch_work_details(work_id):
    base_url = f"http://musicbrainz.org/ws/2/work/{work_id}"
    params = {
        "fmt": "json",
        "inc": "artist-rels"
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch work details for work ID {work_id}")
        return {}
    
artist_name = "Ed Sheeran"
song_name = "Shape of you"

data = fetch_songwriter_producer_musicbrainz(artist_name, song_name)
songwriters, producers = parse_songwriter_producer(data)
print(songwriters, producers)
# Out:
# [] []

# %%
def get_song_url_genius(access_token, artist_name, song_name):
    base_url = "https://api.genius.com/search"
    headers = {"Authorization": f"Bearer {access_token}"}
    params = {"q": f"{artist_name} {song_name}"}
    response = requests.get(base_url, headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        hits = data['response']['hits']
        for hit in hits:
            if artist_name.lower() in hit['result']['primary_artist']['name'].lower():
                return hit['result']['url']
        return "URL not found."
    else:
        return "Failed to fetch data from Genius."

from bs4 import BeautifulSoup

def scrape_song_info_genius(song_url):
    response = requests.get(song_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Assuming 'song_body-lyrics' was a placeholder and the correct class names need to be found
        # Update the class names according to the current page structure
        song_info = soup.find('div', class_='correct-class-for-song-info')
        
        # Assuming the layout for 'Produced by' and 'Written by' sections can be found with updated selectors
        produced_by = 'Not found'
        written_by = 'Not found'
        
        if song_info:
            produced_by_section = song_info.find('div', text='Produced by')
            if produced_by_section:
                produced_by = produced_by_section.find_next_sibling('a').text
                
            written_by_section = song_info.find('div', text='Written by')
            if written_by_section:
                written_by = written_by_section.find_next_sibling('a').text
                
        return {
            'Produced by': produced_by,
            'Written by': written_by
        }
    else:
        return {
            'Produced by': 'Failed to fetch data',
            'Written by': 'Failed to fetch data'
        }


url = get_song_url_genius(genius_access_token, "Ed Sheeran", "Shape of you")
print(url)
print(scrape_song_info_genius(url))
# Out:
# https://genius.com/Ed-sheeran-shape-of-you-lyrics
# {'Produced by': 'Not found', 'Written by': 'Not found'}

# %% [markdown]
# Last.FM API for user data

# %%
base_url = 'http://ws.audioscrobbler.com/2.0/'

def lastfm_get(payload):
    headers = {'user-agent': 'DataCollectorBot'}
    payload['api_key'] = lastfm_api_key
    payload['format'] = 'json'
    response = requests.get(base_url, headers=headers, params=payload)
    return response.json()

# Function for each endpoint
def get_user_info(user):
    payload = {'method': 'user.getinfo', 'user': user}
    return lastfm_get(payload)

def get_loved_tracks(user):
    payload = {'method': 'user.getlovedtracks', 'user': user}
    return lastfm_get(payload)

def get_recent_tracks(user):
    payload = {'method': 'user.getrecenttracks', 'user': user}
    return lastfm_get(payload)

def get_top_albums(user):
    payload = {'method': 'user.gettopalbums', 'user': user}
    return lastfm_get(payload)

def get_top_artists(user):
    payload = {'method': 'user.gettopartists', 'user': user}
    return lastfm_get(payload)

def get_top_tags(user):
    payload = {'method': 'user.gettoptags', 'user': user}
    return lastfm_get(payload)

def get_top_tracks(user):
    payload = {'method': 'user.gettoptracks', 'user': user}
    return lastfm_get(payload)

def get_weekly_album_chart(user):
    payload = {'method': 'user.getweeklyalbumchart', 'user': user}
    return lastfm_get(payload)

def get_weekly_artist_chart(user):
    payload = {'method': 'user.getweeklyartistchart', 'user': user}
    return lastfm_get(payload)

def get_weekly_chart_list(user):
    payload = {'method': 'user.getweeklychartlist', 'user': user}
    return lastfm_get(payload)

def get_weekly_track_chart(user):
    payload = {'method': 'user.getweeklytrackchart', 'user': user}
    return lastfm_get(payload)


user_data = {
    'info': get_user_info('Bans77'),
    'loved_tracks': get_loved_tracks('Bans77'),
    'recent_tracks': get_recent_tracks('Bans77'),
    'top_albums': get_top_albums('Bans77'),
    'top_artists': get_top_artists('Bans77'),
    'top_tags': get_top_tags('Bans77'),
    'top_tracks': get_top_tracks('Bans77'),
    'weekly_album_chart': get_weekly_album_chart('Bans77'),
    'weekly_artist_chart': get_weekly_artist_chart('Bans77'),
    'weekly_chart_list': get_weekly_chart_list('Bans77'),
    'weekly_track_chart': get_weekly_track_chart('Bans77')
}

# %%
recent_tracks = user_data['recent_tracks']

# Print each track with its listen timestamp
for track in recent_tracks['recenttracks']['track']:
    track_name = track['name']
    artist_name = track['artist']['#text']
    # Check if the 'date' key exists
    if 'date' in track:
        listen_time = track['date']['#text']  # Human-readable timestamp
        listen_timestamp = track['date']['uts']  # Unix timestamp
        print(f"{artist_name} - {track_name} listened to at {listen_time} (timestamp: {listen_timestamp})")
    else:
        # If 'date' key does not exist, it might be currently playing
        print(f"{artist_name} - {track_name} is currently playing or missing timestamp data.")
# Out:
# cubbie - Endlos is currently playing or missing timestamp data.
# Clairo - Bags listened to at 19 Feb 2024, 05:21 (timestamp: 1708320087)
# Isabel LaRosa - Older listened to at 19 Feb 2024, 05:04 (timestamp: 1708319068)
# Olivia Rodrigo - Can’t Catch Me Now - from The Hunger Games: The Ballad of Songbirds & Snakes listened to at 19 Feb 2024, 05:01 (timestamp: 1708318864)
# Dilated Peoples - Who's Who listened to at 19 Feb 2024, 04:56 (timestamp: 1708318594)
# Aero Chord - Surface listened to at 19 Feb 2024, 04:52 (timestamp: 1708318341)
# Aero Chord - Break Them listened to at 19 Feb 2024, 04:48 (timestamp: 1708318083)
# Bullet for My Valentine - Hand of Blood listened to at 19 Feb 2024, 04:44 (timestamp: 1708317876)
# The Crystal Method - Born Too Slow listened to at 19 Feb 2024, 04:42 (timestamp: 1708317752)
# The Prodigy - You'll Be Under My Wheels listened to at 19 Feb 2024, 04:38 (timestamp: 1708317515)
# T.I. - 24's listened to at 19 Feb 2024, 04:34 (timestamp: 1708317255)
# P$C - Do Ya Thing (feat. Young Dro) listened to at 19 Feb 2024, 04:29 (timestamp: 1708316991)
# Sofi Tukker - Swing listened to at 19 Feb 2024, 04:26 (timestamp: 1708316798)
# Muse - Butterflies & Hurricanes listened to at 19 Feb 2024, 04:21 (timestamp: 1708316498)
# Rebūke - Digital Dream listened to at 19 Feb 2024, 04:18 (timestamp: 1708316298)
# Billy Talent - Fallen Leaves listened to at 19 Feb 2024, 04:14 (timestamp: 1708316043)
# 52Blue - Blick Über Die Stadt listened to at 19 Feb 2024, 04:11 (timestamp: 1708315876)
# Kidd Azzurra - Sie liebt mich nicht listened to at 19 Feb 2024, 04:09 (timestamp: 1708315770)
# забей, лерочка - Lie listened to at 19 Feb 2024, 03:59 (timestamp: 1708315194)
# Chernikovskaya Hata - Последняя осень listened to at 19 Feb 2024, 03:55 (timestamp: 1708314954)
# Три дня дождя, SHENA? - Отражения listened to at 19 Feb 2024, 03:51 (timestamp: 1708314712)
# Три Дня Дождя - Отражения listened to at 19 Feb 2024, 03:51 (timestamp: 1708314710)
# Три Дня Дождя - За край listened to at 19 Feb 2024, 03:49 (timestamp: 1708314579)
# Три Дня Дождя - За край listened to at 19 Feb 2024, 03:49 (timestamp: 1708314577)
# vioria - Я просто хочу додому listened to at 19 Feb 2024, 03:47 (timestamp: 1708314440)
# vioria - Я просто хочу додому listened to at 19 Feb 2024, 03:47 (timestamp: 1708314436)
# vioria - хвора на любов listened to at 19 Feb 2024, 03:45 (timestamp: 1708314307)
# vioria - хвора на любов listened to at 19 Feb 2024, 03:45 (timestamp: 1708314301)
# vioria - хвора на любов listened to at 19 Feb 2024, 03:42 (timestamp: 1708314170)
# vioria - хвора на любов listened to at 19 Feb 2024, 03:42 (timestamp: 1708314168)
# vioria - хвора на любов listened to at 19 Feb 2024, 03:40 (timestamp: 1708314024)
# vioria - хвора на любов listened to at 19 Feb 2024, 03:40 (timestamp: 1708314021)
# Lil Eyes - ohne dich listened to at 18 Feb 2024, 18:55 (timestamp: 1708282521)
# Matze - herzen listened to at 18 Feb 2024, 18:52 (timestamp: 1708282344)
# Capital Bra - Berlin lebt listened to at 18 Feb 2024, 18:18 (timestamp: 1708280289)
# Capital Bra - Olé Olé listened to at 18 Feb 2024, 18:06 (timestamp: 1708279611)
# Capital Bra, RAF Camora, Joshi Mizu - Olé Olé listened to at 18 Feb 2024, 18:04 (timestamp: 1708279459)
# BEVN - Sex listened to at 18 Feb 2024, 18:01 (timestamp: 1708279266)
# Nugat - Killshot listened to at 18 Feb 2024, 18:01 (timestamp: 1708279266)
# BEVN - Sex listened to at 18 Feb 2024, 17:58 (timestamp: 1708279122)
# Kidd Azzurra - Sie liebt mich nicht listened to at 18 Feb 2024, 17:55 (timestamp: 1708278958)
# Katlix - 115 Tage listened to at 18 Feb 2024, 15:25 (timestamp: 1708269944)
# Maaks - Farblose Welt listened to at 18 Feb 2024, 15:24 (timestamp: 1708269844)
# Nugat - Killshot listened to at 18 Feb 2024, 15:22 (timestamp: 1708269731)
# Nugat - Killshot listened to at 18 Feb 2024, 15:20 (timestamp: 1708269609)
# BEVN - Sex listened to at 18 Feb 2024, 15:20 (timestamp: 1708269604)
# BEVN - Sex listened to at 18 Feb 2024, 15:17 (timestamp: 1708269473)
# Dondon - Problemboy listened to at 18 Feb 2024, 15:17 (timestamp: 1708269459)
# Dondon, YUNGMON - Problemboy listened to at 18 Feb 2024, 15:15 (timestamp: 1708269342)
# Kidd Azzurra - Sie liebt mich nicht listened to at 18 Feb 2024, 15:14 (timestamp: 1708269249)
# Kidd Azzurra - Sie liebt mich nicht listened to at 18 Feb 2024, 15:13 (timestamp: 1708269209)

# %%
import requests
from collections import deque

def get_lastfm_friends_bfs(start_username, api_key, min_users=5000):
    discovered = set([start_username])  # Users that have been discovered
    queue = deque([start_username])     # Users to be explored
    collected_friends = []              # Collected friends

    while queue and len(collected_friends) < min_users:
        current_user = queue.popleft()
        url = f"http://ws.audioscrobbler.com/2.0/?method=user.getfriends&user={current_user}&api_key={api_key}&format=json"
        
        try:
            response = requests.get(url)
            data = response.json()
            
            if 'error' in data:
                print(f"Error fetching data for user {current_user}: {data['message']}")
                continue
            
            users = data.get('friends', {}).get('user', [])
            for user in users:
                friend_name = user['name']
                if friend_name not in discovered:
                    discovered.add(friend_name)
                    queue.append(friend_name)
                    collected_friends.append(friend_name)
                    if len(collected_friends) >= min_users:
                        break  # Stop if we have collected enough friends

            print(f"Collected {len(collected_friends)} friends so far...")
        except Exception as e:
            print(f"An error occurred while processing user {current_user}: {e}")
    
    return collected_friends[:min_users]

# Example usage
# api_key = lastfm_api_key
# start_username = 'Bans77'
# friends = get_lastfm_friends_bfs(start_username, api_key)
# print(f"Collected {len(friends)} unique friends.")

# %%
def get_lastfm_friends_loved_tracks(start_username, api_key, min_users=100, tracks_per_user=50):
    discovered = set([start_username])
    queue = deque([start_username])
    users_loved_tracks = {}  # Dictionary to hold users and their loved tracks

    while queue and len(users_loved_tracks) < min_users:
        current_user = queue.popleft()
        # Fetch friends
        friends_url = f"http://ws.audioscrobbler.com/2.0/?method=user.getfriends&user={current_user}&api_key={api_key}&format=json"
        
        try:
            response = requests.get(friends_url)
            data = response.json()
            
            if 'error' in data:
                print(f"Error fetching data for user {current_user}: {data['message']}")
                continue
            
            users = data.get('friends', {}).get('user', [])
            for user in users:
                friend_name = user['name']
                if friend_name not in discovered:
                    discovered.add(friend_name)
                    queue.append(friend_name)
                    # Fetch loved tracks for this friend
                    tracks_url = f"http://ws.audioscrobbler.com/2.0/?method=user.getlovedtracks&user={friend_name}&api_key={api_key}&format=json&limit={tracks_per_user}"
                    tracks_response = requests.get(tracks_url)
                    tracks_data = tracks_response.json()
                    
                    if 'error' not in tracks_data:
                        loved_tracks = tracks_data.get('lovedtracks', {}).get('track', [])
                        users_loved_tracks[friend_name] = [track['name'] for track in loved_tracks]

            print(f"Collected {len(users_loved_tracks)} users' loved tracks so far...")
        except Exception as e:
            print(f"An error occurred while processing user {current_user}: {e}")
            continue
    
    return users_loved_tracks


api_key = lastfm_api_key
start_username = 'Bans77'
users_loved_tracks = get_lastfm_friends_loved_tracks(start_username, api_key)
print(f"Collected loved tracks for {len(users_loved_tracks)} users.")
# Out:
# Error fetching data for user wyerock: no such page
# Collected loved tracks for 0 users.

# %%
import requests as r
from bs4 import BeautifulSoup
from collections import deque

LAST_FM_URL = "https://www.last.fm/user/"


def get_following_user_names(curr_user_name):
  curr_user_following_URL = LAST_FM_URL + curr_user_name + "/following"
  text = BeautifulSoup(r.get(curr_user_following_URL).text)

  return text



def get_followers_user_names(curr_user_name):
  curr_user_followers_URL = LAST_FM_URL + curr_user_name + "/followers"
  text = BeautifulSoup(r.get(curr_user_followers_URL).text)

  return text


def get_users(): # will cause request timeout
  users = set()
  queue = deque(["bans77", "bouquet-of-sun", "chippy_boi", "joehoots", "czmiles-gb", "bunnycakex", "jakeledoux"])

  while len(queue) != 0:
    curr_size = len(queue)
    for i in range(0, curr_size):
      curr_user = queue.popleft()
      curr_user_follower_text = get_followers_user_names(curr_user)
      for h4 in curr_user_follower_text.find_all(class_="user-list-name"):
        new_user = h4.a.text
        if new_user not in users:
          queue.append(new_user)
      curr_user_follower_text = get_following_user_names(curr_user)
      for h4 in curr_user_follower_text.find_all(class_="user-list-name"):
        new_user = h4.a.text
        if new_user not in users:
          queue.append(new_user)
      users.add(curr_user)

  return users

def get_loved_tracks(username):
  loved_tracks_URL = LAST_FM_URL + username + "/loved"
  text = BeautifulSoup(r.get(loved_tracks_URL).text)

  track_tag = text.find_all('td', class_='chartlist-name')
  tracks = [tag.a.text for tag in track_tag]

  return tracks


def get_data():
  users = get_users()
  data = {}
  for user in users:
    data[user] = get_loved_tracks(user)


  return data

# %%
import requests
from collections import deque
import pandas as pd

def get_lastfm_data(start_username, api_key):
    min_users = 10000
    min_songs = 100000
    discovered = set([start_username])
    queue = deque([start_username])
    users_songs = {}  # This will store user: {"top_50": [], "loved": []}
    all_songs = set()

    while queue and (len(users_songs) < min_users or len(all_songs) < min_songs):
        current_user = queue.popleft()
        
        friends_url = f"http://ws.audioscrobbler.com/2.0/?method=user.getfriends&user={current_user}&api_key={api_key}&format=json"
        try:
            friends_response = requests.get(friends_url)
            friends_data = friends_response.json()
            
            if 'error' in friends_data:
                print(f"Error fetching friends for user {current_user}: {friends_data['message']}")
                continue
            
            for user in friends_data.get('friends', {}).get('user', []):
                friend_name = user['name']
                if friend_name not in discovered:
                    discovered.add(friend_name)
                    queue.append(friend_name)

                    loved_tracks_url = f"http://ws.audioscrobbler.com/2.0/?method=user.getlovedtracks&user={friend_name}&api_key={api_key}&format=json"
                    top_tracks_url = f"http://ws.audioscrobbler.com/2.0/?method=user.gettoptracks&user={friend_name}&api_key={api_key}&format=json&limit=50"
                    
                    loved_tracks_response = requests.get(loved_tracks_url)
                    top_tracks_response = requests.get(top_tracks_url)
                    
                    loved_tracks_data = loved_tracks_response.json()
                    top_tracks_data = top_tracks_response.json()
                    
                    if 'error' not in loved_tracks_data and 'error' not in top_tracks_data:
                        loved_tracks = [track['name'] for track in loved_tracks_data.get('lovedtracks', {}).get('track', [])]
                        top_tracks = [track['name'] for track in top_tracks_data.get('toptracks', {}).get('track', [])]
                        
                        users_songs[friend_name] = {"top_50": top_tracks, "loved": loved_tracks}
                        all_songs.update(loved_tracks, top_tracks)

            print(f"Collected {len(users_songs)} users and {len(all_songs)} unique songs so far...")
        except Exception as e:
            print(f"An error occurred while processing user {current_user}: {e}")
            continue
        
    df = pd.DataFrame([(user, data['top_50'], data['loved']) for user, data in users_songs.items()], columns=['User', 'Top 50 Songs', 'Liked Songs'])
    
    # Save to Excel
    df.to_excel('gabe.xlsx', index=False)
    print("Data saved to lastfm_users_songs.xlsx")
    
    return users_songs

# %%
get_lastfm_data("bouquet-of-sun", lastfm_api_key)
# Out:
# Collected 32 users and 2434 unique songs so far...
# Collected 82 users and 5951 unique songs so far...
# Collected 130 users and 9245 unique songs so far...
# Collected 179 users and 11682 unique songs so far...
# Collected 183 users and 11806 unique songs so far...
# Error fetching friends for user lozzol_: no such page
# Error fetching friends for user selfishpunk: no such page
# Collected 194 users and 12150 unique songs so far...
# Collected 240 users and 14085 unique songs so far...
# Error fetching friends for user Sandman099: no such page
# Collected 289 users and 16318 unique songs so far...
# Collected 335 users and 18699 unique songs so far...
# Collected 382 users and 20294 unique songs so far...
# Collected 414 users and 21599 unique songs so far...
# Collected 463 users and 24126 unique songs so far...
# Collected 468 users and 24211 unique songs so far...
# Collected 481 users and 24568 unique songs so far...
# Collected 514 users and 25856 unique songs so far...
# Collected 557 users and 27820 unique songs so far...
# Collected 566 users and 28201 unique songs so far...
# Collected 615 users and 30327 unique songs so far...
# Collected 662 users and 33025 unique songs so far...
# Collected 706 users and 34866 unique songs so far...
# Collected 752 users and 36009 unique songs so far...
# Collected 772 users and 36765 unique songs so far...
# Collected 787 users and 37175 unique songs so far...
# Collected 835 users and 38729 unique songs so far...
# Collected 854 users and 39204 unique songs so far...
# Collected 901 users and 40835 unique songs so far...
# Error fetching friends for user rodriggam: no such page
# Error fetching friends for user davwi: no such page
# Collected 948 users and 42148 unique songs so far...
# Error fetching friends for user mrkdmnk: no such page
# Error fetching friends for user rydigns: no such page
# Collected 989 users and 43888 unique songs so far...
# Collected 1010 users and 44506 unique songs so far...
# Collected 1060 users and 46363 unique songs so far...
# Collected 1102 users and 47415 unique songs so far...
# Error fetching friends for user christopherjr95: no such page
# Collected 1145 users and 48296 unique songs so far...
# Collected 1185 users and 49563 unique songs so far...
# Collected 1230 users and 51672 unique songs so far...
# Collected 1272 users and 52863 unique songs so far...
# Collected 1279 users and 53047 unique songs so far...
# Collected 1285 users and 53250 unique songs so far...
# Collected 1327 users and 54053 unique songs so far...
# Collected 1355 users and 55343 unique songs so far...
# Error fetching friends for user OlaGa1914: no such page
# Collected 1360 users and 55423 unique songs so far...
# Collected 1397 users and 56296 unique songs so far...
# Collected 1441 users and 57536 unique songs so far...
# Collected 1445 users and 57555 unique songs so far...
# Collected 1494 users and 59330 unique songs so far...
# Collected 1534 users and 60142 unique songs so far...
# Collected 1560 users and 60730 unique songs so far...
# Collected 1609 users and 63064 unique songs so far...
# Collected 1610 users and 63070 unique songs so far...
# Collected 1646 users and 63793 unique songs so far...
# Collected 1693 users and 64888 unique songs so far...
# Collected 1701 users and 64961 unique songs so far...
# Collected 1744 users and 66018 unique songs so far...
# Collected 1770 users and 66872 unique songs so far...
# Collected 1782 users and 67511 unique songs so far...
# Collected 1814 users and 68023 unique songs so far...
# Collected 1860 users and 69495 unique songs so far...
# Collected 1862 users and 69561 unique songs so far...
# Collected 1902 users and 70671 unique songs so far...
# Collected 1949 users and 71705 unique songs so far...
# Error fetching friends for user Pedonika: no such page
# Collected 1951 users and 71808 unique songs so far...
# Collected 1997 users and 73003 unique songs so far...
# Collected 2044 users and 74471 unique songs so far...
# Collected 2070 users and 75073 unique songs so far...
# Collected 2073 users and 75170 unique songs so far...
# Collected 2085 users and 75420 unique songs so far...
# Collected 2130 users and 77322 unique songs so far...
# Collected 2177 users and 78716 unique songs so far...
# Collected 2219 users and 79853 unique songs so far...
# Collected 2258 users and 80674 unique songs so far...
# Collected 2298 users and 81392 unique songs so far...
# Collected 2316 users and 81811 unique songs so far...
# Collected 2319 users and 81869 unique songs so far...
# Collected 2320 users and 81891 unique songs so far...
# Collected 2357 users and 83139 unique songs so far...
# Collected 2366 users and 83304 unique songs so far...
# Collected 2377 users and 83658 unique songs so far...
# Collected 2405 users and 85109 unique songs so far...
# Collected 2440 users and 85734 unique songs so far...
# Collected 2459 users and 86127 unique songs so far...
# Collected 2507 users and 86553 unique songs so far...
# Collected 2554 users and 87905 unique songs so far...
# Collected 2595 users and 90187 unique songs so far...
# Collected 2629 users and 90703 unique songs so far...
# Error fetching friends for user femcelkitty: no such page
# Collected 2671 users and 91798 unique songs so far...
# Error fetching friends for user saultratts: no such page
# Collected 2704 users and 92446 unique songs so far...
# Collected 2741 users and 93297 unique songs so far...
# Collected 2765 users and 93805 unique songs so far...
# Collected 2800 users and 94667 unique songs so far...
# Collected 2812 users and 94872 unique songs so far...
# Collected 2820 users and 95029 unique songs so far...
# Collected 2862 users and 95936 unique songs so far...
# Collected 2907 users and 97513 unique songs so far...
# Collected 2951 users and 98498 unique songs so far...
# Collected 2985 users and 99227 unique songs so far...
# Collected 2994 users and 99518 unique songs so far...
# Collected 3005 users and 100096 unique songs so far...
# Collected 3039 users and 101271 unique songs so far...
# Collected 3072 users and 101908 unique songs so far...
# Collected 3098 users and 102236 unique songs so far...
# Collected 3136 users and 103672 unique songs so far...
# Collected 3162 users and 104873 unique songs so far...
# Collected 3197 users and 106241 unique songs so far...
# Collected 3224 users and 106587 unique songs so far...
# Error fetching friends for user A-W-A-X: no such page
# Collected 3266 users and 108308 unique songs so far...
# Collected 3311 users and 108885 unique songs so far...
# Collected 3350 users and 109378 unique songs so far...
# Collected 3372 users and 109582 unique songs so far...
# Collected 3409 users and 110255 unique songs so far...
# Collected 3455 users and 111748 unique songs so far...
# Error fetching friends for user nfopuhfxir: no such page
# Collected 3502 users and 113448 unique songs so far...
# Error fetching friends for user Sebastien214: no such page
# Collected 3536 users and 114172 unique songs so far...
# Collected 3543 users and 114242 unique songs so far...
# Collected 3555 users and 114584 unique songs so far...
# Error fetching friends for user starfalll: no such page
# Collected 3583 users and 114892 unique songs so far...
# Collected 3587 users and 115044 unique songs so far...
# Collected 3625 users and 116224 unique songs so far...
# Collected 3626 users and 116244 unique songs so far...
# Collected 3649 users and 116444 unique songs so far...
# Collected 3683 users and 117019 unique songs so far...
# Collected 3683 users and 117019 unique songs so far...
# Collected 3713 users and 117405 unique songs so far...
# Collected 3757 users and 118275 unique songs so far...
# Collected 3800 users and 119547 unique songs so far...
# Collected 3816 users and 119644 unique songs so far...
# Collected 3843 users and 120071 unique songs so far...
# Collected 3871 users and 120537 unique songs so far...
# Collected 3911 users and 122000 unique songs so far...
# Collected 3940 users and 122579 unique songs so far...
# Error fetching friends for user wandernoodle: no such page
# Collected 3975 users and 123753 unique songs so far...
# Collected 4002 users and 124298 unique songs so far...
# Collected 4048 users and 125367 unique songs so far...
# Collected 4053 users and 125583 unique songs so far...
# Collected 4095 users and 126538 unique songs so far...
# Collected 4102 users and 126635 unique songs so far...
# Collected 4137 users and 127483 unique songs so far...
# Collected 4163 users and 128121 unique songs so far...
# Error fetching friends for user trashdollxo: no such page
# Collected 4191 users and 128531 unique songs so far...
# Collected 4216 users and 129101 unique songs so far...
# Collected 4243 users and 129406 unique songs so far...
# Collected 4286 users and 129829 unique songs so far...
# Collected 4286 users and 129829 unique songs so far...
# Collected 4325 users and 130810 unique songs so far...
# Collected 4369 users and 131636 unique songs so far...
# Error fetching friends for user NZT3: no such page
# Collected 4388 users and 131874 unique songs so far...
# Collected 4393 users and 131952 unique songs so far...
# Collected 4435 users and 132641 unique songs so far...
# Collected 4442 users and 132751 unique songs so far...
# Collected 4473 users and 133069 unique songs so far...
# Collected 4473 users and 133069 unique songs so far...
# Collected 4487 users and 133496 unique songs so far...
# Collected 4521 users and 133974 unique songs so far...
# Error fetching friends for user gabb0es: no such page
# Collected 4546 users and 134381 unique songs so far...
# Collected 4546 users and 134381 unique songs so far...
# Collected 4589 users and 135496 unique songs so far...
# Collected 4621 users and 135921 unique songs so far...
# Error fetching friends for user catslily: no such page
# Collected 4652 users and 136269 unique songs so far...
# Collected 4677 users and 136524 unique songs so far...
# Collected 4700 users and 136770 unique songs so far...
# Error fetching friends for user ultgia: no such page
# Collected 4701 users and 136772 unique songs so far...
# Collected 4704 users and 136803 unique songs so far...
# Collected 4705 users and 136806 unique songs so far...
# Error fetching friends for user cryptofyre: no such page
# Error fetching friends for user spam0004: no such page
# Error fetching friends for user Shibuya_7: no such page
# Error fetching friends for user dhroov_: no such page
# Collected 4706 users and 136809 unique songs so far...
# Collected 4728 users and 137175 unique songs so far...
# Error fetching friends for user unfuckwithadam: no such page
# Collected 4733 users and 137231 unique songs so far...
# Error fetching friends for user ThenuSand: no such page
# Collected 4780 users and 137796 unique songs so far...
# Collected 4780 users and 137796 unique songs so far...
# Collected 4780 users and 137796 unique songs so far...
# Collected 4822 users and 138634 unique songs so far...
# Collected 4853 users and 138959 unique songs so far...
# Collected 4862 users and 139190 unique songs so far...
# Error fetching friends for user bencarey666: no such page
# Collected 4909 users and 140545 unique songs so far...
# Collected 4925 users and 140708 unique songs so far...
# Collected 4932 users and 140789 unique songs so far...
# Collected 4936 users and 140867 unique songs so far...
# Collected 4937 users and 140870 unique songs so far...
# Collected 4961 users and 141060 unique songs so far...
# Collected 4995 users and 141516 unique songs so far...
# Collected 5019 users and 141790 unique songs so far...
# Collected 5042 users and 142127 unique songs so far...
# Collected 5044 users and 142150 unique songs so far...
# Collected 5090 users and 143089 unique songs so far...
# Collected 5117 users and 143339 unique songs so far...
# Collected 5155 users and 143504 unique songs so far...
# Collected 5158 users and 143549 unique songs so far...
# Collected 5188 users and 144042 unique songs so far...
# Error fetching friends for user brandonwav: no such page
# Collected 5209 users and 144248 unique songs so far...
# Collected 5225 users and 144421 unique songs so far...
# Collected 5235 users and 144688 unique songs so far...
# Collected 5257 users and 145074 unique songs so far...
# Collected 5282 users and 145446 unique songs so far...
# Collected 5323 users and 145878 unique songs so far...
# Collected 5330 users and 145916 unique songs so far...
# Collected 5376 users and 146194 unique songs so far...
# Collected 5410 users and 146457 unique songs so far...
# Collected 5415 users and 146674 unique songs so far...
# Collected 5448 users and 147227 unique songs so far...
# Collected 5468 users and 147368 unique songs so far...
# Collected 5497 users and 147782 unique songs so far...
# Error fetching friends for user swifteez: no such page
# Collected 5544 users and 148293 unique songs so far...
# Collected 5568 users and 148464 unique songs so far...
# Collected 5573 users and 148533 unique songs so far...
# Collected 5614 users and 148788 unique songs so far...
# Collected 5643 users and 149054 unique songs so far...
# Collected 5665 users and 149403 unique songs so far...
# Collected 5694 users and 149512 unique songs so far...
# Collected 5715 users and 149687 unique songs so far...
# Collected 5738 users and 149991 unique songs so far...
# Collected 5771 users and 150464 unique songs so far...
# Collected 5807 users and 150872 unique songs so far...
# Error fetching friends for user akimenz: no such page
# Collected 5818 users and 151017 unique songs so far...
# Collected 5848 users and 151434 unique songs so far...
# Collected 5883 users and 152133 unique songs so far...
# Collected 5924 users and 152747 unique songs so far...
# Collected 5955 users and 153435 unique songs so far...
# Collected 5958 users and 153466 unique songs so far...
# Error fetching friends for user Pigeon_MGK: no such page
# Collected 5982 users and 153622 unique songs so far...
# Collected 6012 users and 154066 unique songs so far...
# Collected 6035 users and 154189 unique songs so far...
# Collected 6054 users and 154331 unique songs so far...
# Error fetching friends for user solarium_0: no such page
# Collected 6083 users and 154988 unique songs so far...
# Collected 6127 users and 156803 unique songs so far...
# Collected 6137 users and 157064 unique songs so far...
# Collected 6177 users and 157951 unique songs so far...
# Collected 6201 users and 158217 unique songs so far...
# Collected 6233 users and 158400 unique songs so far...
# Collected 6233 users and 158400 unique songs so far...
# Collected 6269 users and 159291 unique songs so far...
# Collected 6295 users and 159542 unique songs so far...
# Collected 6326 users and 159892 unique songs so far...
# Collected 6345 users and 160039 unique songs so far...
# Collected 6378 users and 160347 unique songs so far...
# Collected 6387 users and 160455 unique songs so far...
# Collected 6434 users and 161202 unique songs so far...
# Collected 6481 users and 162156 unique songs so far...
# Collected 6516 users and 162885 unique songs so far...
# Collected 6553 users and 163269 unique songs so far...
# Collected 6586 users and 163838 unique songs so far...
# Collected 6609 users and 163988 unique songs so far...
# Collected 6613 users and 164025 unique songs so far...
# Collected 6642 users and 164498 unique songs so far...
# Collected 6665 users and 164918 unique songs so far...
# Collected 6687 users and 165171 unique songs so far...
# Collected 6712 users and 165424 unique songs so far...
# Collected 6730 users and 165653 unique songs so far...
# Collected 6774 users and 166232 unique songs so far...
# Collected 6790 users and 166598 unique songs so far...
# Collected 6831 users and 167744 unique songs so far...
# Collected 6852 users and 168241 unique songs so far...
# Collected 6875 users and 168429 unique songs so far...
# Collected 6904 users and 169011 unique songs so far...
# Collected 6905 users and 169014 unique songs so far...
# Collected 6920 users and 169181 unique songs so far...
# Collected 6940 users and 169421 unique songs so far...
# Collected 6974 users and 170268 unique songs so far...
# Error fetching friends for user FifthofNovember: no such page
# Collected 7011 users and 171040 unique songs so far...
# Collected 7014 users and 171116 unique songs so far...
# Collected 7040 users and 171301 unique songs so far...
# Collected 7041 users and 171339 unique songs so far...
# Collected 7069 users and 171798 unique songs so far...
# Collected 7094 users and 172195 unique songs so far...
# Collected 7130 users and 173350 unique songs so far...
# Collected 7151 users and 173490 unique songs so far...
# Error fetching friends for user bBoo_: no such page
# Collected 7159 users and 173628 unique songs so far...
# Collected 7198 users and 175168 unique songs so far...
# Collected 7246 users and 176876 unique songs so far...
# Error fetching friends for user Lena_303: no such page
# Collected 7273 users and 177679 unique songs so far...
# Collected 7291 users and 177874 unique songs so far...
# Error fetching friends for user jpachecofs: no such page
# Collected 7292 users and 177890 unique songs so far...
# Collected 7299 users and 178140 unique songs so far...
# Error fetching friends for user EnbieTrash: no such page
# Collected 7310 users and 178461 unique songs so far...
# Error fetching friends for user pitchdiscontent: no such page
# Collected 7341 users and 179356 unique songs so far...
# Error fetching friends for user jama33: no such page
# Collected 7378 users and 180783 unique songs so far...
# Error fetching friends for user ghostxcookies: no such page
# Collected 7424 users and 182609 unique songs so far...
# Collected 7467 users and 183371 unique songs so far...
# Collected 7495 users and 183799 unique songs so far...
# Collected 7540 users and 185339 unique songs so far...
# Collected 7586 users and 186862 unique songs so far...
# Error fetching friends for user MoonRat122: no such page
# Collected 7605 users and 187244 unique songs so far...
# Collected 7613 users and 187452 unique songs so far...
# Collected 7651 users and 188151 unique songs so far...
# Error fetching friends for user Rubyofthesea: no such page
# Error fetching friends for user Mollymaukerie: no such page
# Error fetching friends for user Dannob10: no such page
# Collected 7672 users and 188731 unique songs so far...
# Error fetching friends for user joghurtdrop: no such page
# Collected 7713 users and 189787 unique songs so far...
# Collected 7760 users and 190736 unique songs so far...
# Error fetching friends for user ajax9923: no such page
# Error fetching friends for user salad_on_toast: no such page
# Collected 7763 users and 190780 unique songs so far...
# Collected 7766 users and 190868 unique songs so far...
# Collected 7768 users and 190931 unique songs so far...
# Collected 7782 users and 191161 unique songs so far...
# Collected 7802 users and 191278 unique songs so far...
# Collected 7803 users and 191347 unique songs so far...
# Collected 7837 users and 191785 unique songs so far...
# Collected 7860 users and 192056 unique songs so far...
# Collected 7890 users and 192558 unique songs so far...
# Collected 7911 users and 192730 unique songs so far...
# Collected 7945 users and 193303 unique songs so far...
# Error fetching friends for user anxiousan0n: no such page
# Collected 7948 users and 193311 unique songs so far...
# Collected 7971 users and 193957 unique songs so far...
# Collected 8006 users and 194439 unique songs so far...
# Collected 8009 users and 194455 unique songs so far...
# Collected 8037 users and 194534 unique songs so far...
# Collected 8072 users and 194817 unique songs so far...
# Collected 8114 users and 195225 unique songs so far...
# Collected 8158 users and 195746 unique songs so far...
# Collected 8176 users and 195816 unique songs so far...
# Collected 8198 users and 195853 unique songs so far...
# Collected 8205 users and 196076 unique songs so far...
# Collected 8211 users and 196148 unique songs so far...
# Collected 8254 users and 197335 unique songs so far...
# Collected 8287 users and 198227 unique songs so far...
# Collected 8301 users and 198523 unique songs so far...
# Collected 8321 users and 198675 unique songs so far...
# Collected 8350 users and 199143 unique songs so far...
# Collected 8383 users and 199829 unique songs so far...
# Collected 8387 users and 199909 unique songs so far...
# Collected 8401 users and 200054 unique songs so far...
# Collected 8420 users and 200291 unique songs so far...
# Collected 8448 users and 201042 unique songs so far...
# Error fetching friends for user fairylynaa: no such page
# Collected 8487 users and 202208 unique songs so far...
# Collected 8523 users and 202489 unique songs so far...
# Collected 8541 users and 202601 unique songs so far...
# Error fetching friends for user shahadstansbts: no such page
# Error fetching friends for user sleepy_lag00n: no such page
# Collected 8544 users and 202613 unique songs so far...
# Collected 8545 users and 202614 unique songs so far...
# Error fetching friends for user evrndro: no such page
# Error fetching friends for user NoWorthyIcons: no such page
# Collected 8558 users and 202937 unique songs so far...
# Collected 8591 users and 203160 unique songs so far...
# Collected 8609 users and 203393 unique songs so far...
# Collected 8635 users and 203620 unique songs so far...
# Collected 8638 users and 203626 unique songs so far...
# Collected 8655 users and 203712 unique songs so far...
# Collected 8669 users and 203830 unique songs so far...
# Collected 8684 users and 204179 unique songs so far...
# Error fetching friends for user Sapphicgoblin: no such page
# Error fetching friends for user KyllanOaks: no such page
# Error fetching friends for user Phenix_2004: no such page
# Error fetching friends for user EcorteYT: no such page
# Collected 8685 users and 204239 unique songs so far...
# Error fetching friends for user Tueurs: no such page
# Collected 8715 users and 204986 unique songs so far...
# Collected 8718 users and 205014 unique songs so far...
# Error fetching friends for user NLGF: no such page
# Collected 8736 users and 205789 unique songs so far...
# Collected 8740 users and 206002 unique songs so far...
# Collected 8741 users and 206041 unique songs so far...
# Collected 8756 users and 206277 unique songs so far...
# Error fetching friends for user SUPERJEFF6: no such page
# Collected 8802 users and 207945 unique songs so far...
# Collected 8806 users and 208113 unique songs so far...
# Collected 8841 users and 208313 unique songs so far...
# Error fetching friends for user Smalius: no such page
# Collected 8887 users and 209081 unique songs so far...
# Collected 8893 users and 209185 unique songs so far...
# Collected 8902 users and 209288 unique songs so far...
# Collected 8941 users and 209859 unique songs so far...
# Collected 8944 users and 209921 unique songs so far...
# Collected 8950 users and 209996 unique songs so far...
# Collected 8992 users and 211439 unique songs so far...
# Collected 9020 users and 211945 unique songs so far...
# Error fetching friends for user sorpp: no such page
# Collected 9026 users and 212010 unique songs so far...
# Collected 9073 users and 213869 unique songs so far...
# Collected 9118 users and 214524 unique songs so far...
# Error fetching friends for user Bakkabak: no such page
# Collected 9163 users and 214779 unique songs so far...
# Collected 9209 users and 215579 unique songs so far...
# Collected 9250 users and 215922 unique songs so far...
# Collected 9298 users and 217218 unique songs so far...
# Collected 9314 users and 217625 unique songs so far...
# Collected 9342 users and 217793 unique songs so far...
# Collected 9378 users and 218284 unique songs so far...
# Collected 9419 users and 218482 unique songs so far...
# Collected 9453 users and 219052 unique songs so far...
# Collected 9502 users and 219366 unique songs so far...
# Error fetching friends for user artadaxsh: no such page
# Collected 9531 users and 220430 unique songs so far...
# Collected 9572 users and 221246 unique songs so far...
# Collected 9583 users and 221428 unique songs so far...
# Collected 9623 users and 221632 unique songs so far...
# Collected 9633 users and 221699 unique songs so far...
# Collected 9665 users and 222358 unique songs so far...
# Collected 9682 users and 222537 unique songs so far...
# Collected 9722 users and 223211 unique songs so far...
# Collected 9768 users and 224532 unique songs so far...
# Collected 9809 users and 224776 unique songs so far...
# Collected 9848 users and 224946 unique songs so far...
# Collected 9886 users and 226005 unique songs so far...
# Collected 9921 users and 226344 unique songs so far...
# Collected 9964 users and 226794 unique songs so far...
# Collected 9997 users and 227437 unique songs so far...
# Collected 9998 users and 227449 unique songs so far...
# Collected 9999 users and 227452 unique songs so far...
# Collected 10042 users and 228447 unique songs so far...
# Data saved to lastfm_users_songs.xlsx
# {'quicksandz': {'top_50': ['Selfish',
#    'Quicksand',
#    'AMERICAN GURL',
#    'Demon',
#    'Jackie',
#    'Ride With Me',
#    'Woman',
#    '10%',
#    'I Want',
#    'Selfish Soul',
#    'Gospel for a New Century',
#    'umbrellar',
#    'Doorman',
#    'Feel Good Inc.',
#    'Awake',
#    'Hedonism (Just Because You Feel Good)',
#    'Baby Powder',
#    "It's Been A Little Heavy Lately",
#    'Illusions',
#    "Feet Don't Fail Me Now",
#    'The Less I Know the Better',
#    'Introvert',
#    'Kyoto',
#    'BB',
#    'Army of Me',
#    '212 (feat. Lazy Jay)',
#    'This Enchanted',
#    'Tyrant (feat. Jorja Smith)',
#    'Rewind',
#    'I Love You I Hate You',
#    'BITE ME',
#    'The Key to Life on Earth',
#    'Glory Box',
#    'Nothing Matters',
#    'Hu Man',
#    "So Hot You're Hurting My Feelings",
#    'NICE OUT',
#    'Be Sweet',
#    'Zatoichi',
#    "how will i rest in peace if i'm buried by a highway?//",
#    'Confessions',
#    'Happy Ending',
#    "I'm Not in Love",
#    'Sour Times',
#    'SLIME',
#    'Spotlight',
#    'Bashiri',
#    'Darker Place',
#    'DARE',
#    'Lava/Treacle'],
#   'loved': ['Somebody That I Used to Know',
#    'Zari',
#    'Atmosféra',
#    'Kiss Me',
#    'Suddenly I See',
#    'Release Me',
#    'Send It Up',
#    'Iconic!',
#    'Not the Same',
#    'Valerie - Live At BBC Radio 1 Live Lounge, London / 2007',
#    'Burn It to the Ground',
#    'Numb',
#    "Mowgli's Road",
#    'Demasiadas Mujeres',
#    'Watch Me',
#    'Payback',
#    'Pills',
#    'Broken Man',
#    'Torch',
#    '50ft Queenie',
#    'Snake',
#    'Labios Mordidos (with KAROL G)',
#    'Rim Tim Tagi Dim',
#    'Young Drunk Driver',
#    'Anæmic Adonis',
#    'Hurricane Drunk',
#    'Kiss With a Fist',
#    'EVERYBODY LOVES A WINNER',
#    'RATATA',
#    'A.U.T.I.S.M',
#    'Vagina',
#    'Angel',
#    'ooh',
#    'You Slept on Me',
#    'Off with Her Tits',
#    'Black Eye',
#    'STRIPPER',
#    'Due vite',
#    'Ktheju tokës',
#    'She likes a boy',
#    'Veleno',
#    'Camille',
#    'In Your Eyes',
#    'Zulu Screams (feat. Maleek Berry & Bibi Bourelly)',
#    'Running',
#    'Hello',
#    'Foreign Things - High Contrast Remix',
#    'The World’s Biggest Paving Slab',
#    '(nendest) narkootikumidest ei tea me (küll) midagi',
#    'La La Love']},
#  'fencethetrader': {'top_50': ['Island',
#    'Mother Puncher',
#    'Swamp Song',
#    'Parabola',
#    'Crystals',
#    'Jambi',
#    'Anesthetize',
#    'Zero',
#    'We Die Young',
#    'Noone Love You',
#    'Give a Little',
#    'For You',
#    'Exfiltration',
#    'Unsung',
#    'Taste in Men',
#    'She',
#    'Carolina - From the Motion Picture “Where the Crawdads Sing”',
#    'Eclipse',
#    'Hostile Illusion',
#    'Sober',
#    "No, You Don't",
#    'Say It',
#    'люди надоели',
#    'The Law',
#    'In Fiction',
#    'Pull Me Under',
#    'jimmy',
#    'Forever',
#    'CLAVAR LA ESPADA',
#    'Der Meister',
#    'Prison Sex',
#    'In the Meantime',
#    'Hooker With a Penis',
#    'Alguien Como Tú',
#    '21',
#    'Masâr',
#    'Countdown',
#    'Triad',
#    'Sweat',
#    'Love at First Sight',
#    'Isolation',
#    'Hoy El Aire Huele A Ti',
#    'Let Me Get Me',
#    'Betrayal',
#    'Fear of a Blank Planet',
#    'Parabol',
#    'Wasabi',
#    'Honey Bucket',
#    'Alabina',
#    'Iron Tusk'],
#   'loved': ['Sömürgeci',
#    'The angriest and longest scav voice line I have ever heard #eft',
#    'Son Sözler',
#    'Hakan Yagar Su içiyor',
#    'Intro',
#    'Nasıl Bir Ortam Vardı?',
#    "TEXAS HOLD 'EM",
#    'Hakan Yagar bana inanmıyorsan git onlara inan',
#    'Hold the Sun',
#    'Sugar',
#    'Underground',
#    'Silk in the Strings',
#    "Don't",
#    'The Thrill',
#    'Hold Me Down',
#    'Eleven',
#    'Dance Miserable',
#    'End This (L.O.V.E.)',
#    'How Do You Feel Right Now',
#    'Lottery',
#    'Ruin the Friendship',
#    'Melt Away',
#    'Theme of Laura',
#    'Wounds',
#    'Everything To Everyone - Extended Version',
#    'Forever',
#    'Back on 74',
#    'Luscious Apparatus',
#    'the lakes (bonus track)',
#    'XX',
#    'Inamorata',
#    'Cupid - Twin Ver.',
#    'Picture Perfect',
#    'For You',
#    'Love at First Sight',
#    'I Can See Clearly Now',
#    'Red River Cargo',
#    'LIL FADE',
#    'Te Espero Sentada',
#    'Amante del Amor',
#    'The Wedge',
#    'The Heaviest Matter of the Universe',
#    'Babydoll',
#    'Colorado',
#    'Oro de Ley',
#    'крыши',
#    'Me & My Girls',
#    'Mystery Dance',
#    '(-) Ions',
#    'Alguien Como Tú']},
#  'aria-amethyst': {'top_50': ['My Name is Dark - Algorithm Mix',
#    'Kill V. Maim',
#    "You'll miss me when I'm not around",
#    'Pink (Freak)',
#    'Pin',
#    'Genesis',
#    'Saccharine',
#    'You Lose!',
#    'Yandere',
#    'Player of Games',
#    'Violence - Original Mix',
#    'Chaeri',
#    'Mercurial World',
#    'Flesh without Blood',
#    'Teardrops',
#    'Play Destroy',
#    'Oblivion',
#    'We Appreciate Power',
#    'Follow You',
#    'Before the fever',
#    'Venus Fly',
#    'Shadow Moses',
#    '4ÆM',
#    'EVIL',
#    'nihilist blues (feat. Grimes)',
#    "i don't get a break",
#    'New Gods',
#    'Be a Body (侘寂)',
#    'Can You Feel My Heart',
#    'Sour Switchblade',
#    'TV Head',
#    'World Princess Part II',
#    'Secrets (Your Fire)',
#    'LEGEND',
#    'Rubies',
#    'Weird',
#    'REALiTi',
#    'Forgiveness',
#    'Parasite Eve',
#    'Throne',
#    'Life in the Vivid Dream',
#    'Washing Machine Heart',
#    'Doomed',
#    'SRY ILY',
#    'Pass the Nirvana',
#    'Dawning Of The Season',
#    'Shinigami Eyes',
#    '好き好き大好き - 2016 Remaster',
#    'Fear of Dying',
#    'I Disagree'],
#   'loved': ['The Boy Who Could Fly',
#    'The New National Anthem',
#    'Fast Times at Clairemont High',
#    'One Hundred Sleepless Nights',
#    'The Divine Zero',
#    'She Sings in the Morning',
#    'May These Noises Startle You in Your Sleep Tonight',
#    'Southern Constellations',
#    'Bulletproof Love',
#    'The Sky Under the Sea',
#    'Shared Trauma',
#    'Emergency Contact',
#    "I Don't Care",
#    'stay mad',
#    "I Don't Care Nightcore",
#    '人為機器 (Humans Become Machines)',
#    'Picture Me Better',
#    'ARTPOP',
#    'Overcompensate',
#    'Beast Infection (Nightcore Mix)',
#    'Sardaukar Levanbrech (Reverse Nightcore Mix)',
#    'Venus in Fleurs (Nightcore Mix)',
#    'Let’s Get The Party Started (feat. Bring Me The Horizon)',
#    'TV Dream',
#    'Anything',
#    'mars',
#    'it’s called faith, honey (feat. MYTH)',
#    "Honey I'm Home",
#    'Ancient Dreams in a Modern Land',
#    'Perfect Nothing',
#    'V.A.N',
#    "Build God, Then We'll Talk",
#    "There's a Good Reason These Tables Are Numbered Honey, You Just Haven't Thought of It Yet",
#    "But It's Better If You Do",
#    'I Write Sins Not Tragedies',
#    'Time to Dance',
#    'Nails for Breakfast, Tacks for Snacks',
#    'He Loves Me (He Loves Me Not)',
#    'Coffee',
#    'Pure As A Lamb',
#    'The Mind Electric',
#    'demolition (Ruined by Glass Petals)',
#    'Naughty',
#    'Moonlight (demon)',
#    'Pretty and Depressed',
#    'I / Me / Myself',
#    'Little Bit',
#    'Heavy Metal Lover',
#    'Nobody Puts Baby in the Corner',
#    'Liar (It Takes One to Know One)']},
#  'shoesishere': {'top_50': ['Gucci Prada Balenciaga',
#    'Sugar Wraith',
#    'SUGAR (Remix) [feat. Dua Lipa]',
#    'Crying in the Carwash',
#    'SOMEBODY',
#    'Gone',
#    'stfu (i got u)',
#    'YOU',
#    'Give Me Time',
#    'Lush Life',
#    'ASMR',
#    'PIRATE RADIO*',
#    'Encore',
#    'FREE ME',
#    'Outta Here',
#    'Lo vas a olvidar (with ROSALÍA)',
#    'SLIDE',
#    'MADNESS',
#    'Take What You Want (feat. Ozzy Osbourne & Travis Scott)',
#    'Talk About Love (feat. Young Thug)',
#    'Take Me Down',
#    "I Don't Do Drugs (feat. Ariana Grande)",
#    'Play Fight (with Tinashe)',
#    'Demeanor (feat. Dua Lipa)',
#    'P*$$Y Fairy (OTW)',
#    'hookah envenena',
#    'Do it Again',
#    'I love you baby',
#    'MONEY ON THE DASH',
#    "Baby, I'm Jealous - Stripped",
#    'Problems',
#    'You Right',
#    'positions',
#    'Speed Drive',
#    'CAN THEY HEAR US (From ‘Gully’ with original Daniel Heath Score)',
#    'Loner',
#    'Cheating on You',
#    'everything',
#    'Sunday',
#    'Blame',
#    'Glass of Whisky',
#    'CHAMPION',
#    'Softly',
#    'Tokyo Drifting',
#    'Dally (feat. GRAY)',
#    'August Diaries',
#    'Qué Más Pues?',
#    'Die for Me (feat. Future & Halsey)',
#    'Sip It',
#    'Sad!'],
#   'loved': ['Ur Best Friend (with Kehlani)',
#    'Loneliest Time Of Year',
#    'Trying',
#    'Melrose',
#    'get better',
#    'party in my head (ur not invited)',
#    'Gucci Prada Balenciaga',
#    'The Falls',
#    'PIRATE RADIO*',
#    'Velcro (feat. Gus Dapperton)',
#    'lush',
#    'Think About Me',
#    'SLIDE',
#    'PLEASEXANNY',
#    'Love Quotes',
#    'Mellow Eyes',
#    'Pretty (feat. Mahalia)',
#    'Lush Life',
#    'Dancing With A Stranger',
#    'ride for me (feat. John Concepcion)',
#    'Luv',
#    'inhibitions (feat. P-Lo)',
#    'Runaway (feat. Khalid)',
#    'Entirely',
#    'oasis',
#    'any given sunday (feat. blxst)',
#    'everything',
#    'Monica Lewinsky',
#    'Booty Call',
#    'Superman',
#    'YOU',
#    'meaow',
#    'miracle',
#    'Outta Here',
#    'Lock It Up (feat. THEY.)',
#    'West Coast Love',
#    'All That (feat. Channel Tres)',
#    'Sleepwalking',
#    'Gone',
#    'Pirouette',
#    'exclusive',
#    'exclusive',
#    'Sugar Wraith',
#    'Bubbles',
#    'Gentle Songs for Cats',
#    "I Don't Do Drugs (feat. Ariana Grande)",
#    "Baby, I'm Jealous - Stripped",
#    'Hard to Love',
#    'Need You Like That',
#    'Kiss and Make Up']},
#  'lozzol_': {'top_50': ['Gone',
#    'Jóga',
#    'mary magdalene',
#    'Ta Reine',
#    'MALAMENTE (Cap.1: Augurio)',
#    "It's Okay to Cry",
#    'Bags',
#    'bad idea',
#    'Catboys',
#    'Goya ! Soda !',
#    'Track 10',
#    'True',
#    'BAGDAD (Cap.7: Liturgia)',
#    'sad day',
#    'Kein Wort (feat. Miksu / Macloud)',
#    'PIENSO EN TU MIRÁ (Cap.3: Celos)',
#    'DI MI NOMBRE (Cap.8: Éxtasis)',
#    'Backseat (feat. Carly Rae Jepsen)',
#    'Drugs (feat. ABRA)',
#    'Damn, dis-moi (feat. Dâm-Funk)',
#    'Two Weeks',
#    'Tu me regardes',
#    'Femmebot (feat. Dorian Electra and Mykki Blanco)',
#    'Silver Cross',
#    'Dust',
#    'Des feux pour voir',
#    'i love you',
#    'Your Type',
#    '1999',
#    'Flemme',
#    'Kicks',
#    'Le sexe des étoiles',
#    'Deception Bay',
#    'Delicious (feat. Tommy Cash)',
#    'Out of My Head (feat. Tove Lo and ALMA)',
#    "J'aurai les cheveux longs",
#    'All That',
#    'I Got It (feat. Brooke Candy, CupcakKe and Pabllo Vittar)',
#    'cellophane',
#    'SLIME',
#    'Caramel (feat. Xela Edna)',
#    "I Didn't Just Come Here to Dance",
#    "So Hot You're Hurting My Feelings",
#    'Set Me Free (Feel My Pain)',
#    'Crier Tout Bas',
#    'Love Again',
#    'holy terrain (feat. Future)',
#    'Cherry',
#    'Con Altura (feat. El Guincho)',
#    'Pour toi'],
#   'loved': []},
#  'selfishpunk': {'top_50': ['Stupid Love',
#    'Daddy Lessons',
#    'Writer in the Dark',
#    'Cinnamon Girl',
#    'Rain on Me (with Ariana Grande)',
#    'Envolver',
#    "Don't Start Now",
#    "I'll Never Love Again - Extended Version",
#    'Venus',
#    'Sour Candy (with BLACKPINK)',
#    'Physical',
#    'Alice',
#    'Always Remember Us This Way',
#    'Enigma',
#    'Babylon',
#    'The Greatest',
#    'Shallow',
#    'willow',
#    '7 rings',
#    'Flowers',
#    'Paparazzi',
#    'Break My Heart',
#    'Midnight Sky',
#    '911',
#    'Blinding Lights',
#    'False God',
#    'Fun Tonight',
#    'Free Woman',
#    'Hair',
#    'Look What You Made Me Do',
#    'Shake It Off',
#    'Bad Romance',
#    'Angels Like You',
#    'Yoü and I',
#    'Delicate',
#    'Amor de Que',
#    'You should be sad',
#    'Born This Way',
#    'Poker Face',
#    'California',
#    'Formation',
#    'Blur',
#    'Marry the Night',
#    'Man Down',
#    'DESPECHÁ',
#    'Fashion!',
#    "What's My Name?",
#    'Sad Beautiful Tragic',
#    'Blank Space',
#    'Love on the Brain'],
#   'loved': ['Killing Me',
#    "we can't be friends (wait for your love)",
#    'Heavy Metal Lover',
#    'Art Deco',
#    "'tis the damn season",
#    'NAGASAKI',
#    'The Big Big Beat',
#    'Acontece que no es poco | Independencia de Brasil',
#    'Ditto',
#    'Nobody Gets Me',
#    'Tanto Faz',
#    'Flowers',
#    'Raba',
#    'Nicky Mitrava - Money (feat. Lafayetty) [Official Video]',
#    'Government Hooker',
#    'Americano',
#    'Judas',
#    'Scheiße',
#    'Bloody Mary',
#    'Black Jesus † Amen Fashion',
#    'Bad Kids',
#    'Fashion of His Love',
#    'ARTPOP',
#    'Fashion!',
#    'Buzzcut Season',
#    'Ribs',
#    'Marry the Night',
#    'Vínculo Nenhum',
#    'Unholy (feat. Kim Petras)',
#    'ALIEN SUPERSTAR',
#    'DIABLO',
#    'Frankenstein',
#    '[4K Ultra HD] Anitta - Onda Diferente AO VIVO no Rock in Rio Lisboa 2022',
#    'Campanha de Lula 2002 2 Turno',
#    'CANDY',
#    'SAOKO',
#    'Buonasera (feat. Katuxa Close & Natasha Simonini)',
#    "You're the One That I Want",
#    'Sandcastles',
#    'Babylon - Bree Runway & Jimmy Edgar Remix',
#    'Free Woman - Rina Sawayama & Clarence Clarity Remix',
#    'Fun Tonight - Pabllo Vittar Remix',
#    'Noite de Forró',
#    'Drowned World / Substitute For Love (Live)',
#    'Juliette',
#    'BED (David Guetta Festival Mix)',
#    'te pongo mal(prendelo)',
#    'telepatía',
#    'Vete',
#    'Ignorantes']},
#  'Actualsheep': {'top_50': ['Man Down',
#    'Untitled',
#    'Times Like These',
#    'rock + roll',
#    'drowning.',
#    'isohel',
#    'Jupiter',
#    'Chasing Ghosts',
#    'start//end',
#    'Fumes',
#    'Lost',
#    'Crazy in Love',
#    'Soul',
#    'projector',
#    'The Fire',
#    '909',
#    'love, death, distraction',
#    'drugs',
#    'woah',
#    'Blank_Space',
#    'End Credits',
#    'Circles',
#    'forever//over',
#    'Wake Up',
#    'good morning',
#    'in',
#    'Wings',
#    'falling in reverse',
#    'love; not wrong (brave)',
#    'crash',
#    '2020',
#    '????',
#    'XO',
#    'and',
#    'Gravity',
#    'fomo',
#    'float',
#    'rushing',
#    'Gone',
#    'hertz',
#    'sex',
#    'gold',
#    'modern warfare',
#    'Nocturne',
#    'calm down',
#    'Balling',
#    'just saying',
#    'icarus',
#    'how to sleep',
#    'Interlude'],
#   'loved': ['Genocidal Humanoidz',
#    'Hypnotize',
#    'Toxicity',
#    'Chop Suey!',
#    'Aerials',
#    'Chasing Ghosts',
#    'caffeine',
#    'Dreamer',
#    'venus fly trap',
#    'modern warfare',
#    'Waiting Room',
#    'Closer 2',
#    'PS1',
#    'call me back',
#    'Duvidha',
#    'Elsewhere',
#    'Balling',
#    'A Call',
#    'Reaching 2',
#    'Sci-Fi',
#    'Cry with you',
#    'Six Feet Under',
#    'A Concert Six Months From Now',
#    'Remember This',
#    'Caroline',
#    'Statues (Feat. Leah Kelly)',
#    'Nothing',
#    'The Wisp Sings',
#    'I Hate You So Much',
#    'Way It Goes',
#    'Lost My Mind',
#    'I Lost a Friend',
#    "I'm in Love Without You",
#    'Sunflower',
#    'Life Moves On',
#    "Let's Fall in Love for the Night",
#    'Yours Now',
#    'Break My Heart Again',
#    'Stomach It',
#    'Lonely (with benny blanco)',
#    'emily',
#    'End (Stripped.)',
#    'julia',
#    'Walk Above the City (feat. Maro)',
#    'IDK Love',
#    'Fumes',
#    'drowning.',
#    'full stop',
#    'crash',
#    'Your Power']},
#  'barIey': {'top_50': ['Love Language',
#    'Mosquito',
#    'Summertime',
#    'Normal Girl',
#    'Drew Barrymore',
#    'Supermodel',
#    'Cardboard Box',
#    'Doves in the Wind (feat. Kendrick Lamar)',
#    'Hit Different',
#    '20 Something',
#    'Moment 4 Life',
#    'Shirt',
#    'Feature Me',
#    'Love Galore (feat. Travis Scott)',
#    'Go Gina',
#    'Prom',
#    'Do It',
#    'Immature',
#    'Blind',
#    'Good Days',
#    'The Other Side (from Trolls World Tour)',
#    'The Weekend',
#    'Water',
#    'Snooze',
#    'Garden (Say It Like Dat)',
#    'Anything',
#    "Boy's a liar Pt. 2",
#    'Broken Clocks',
#    'I Hate U',
#    'saturn',
#    "break up with your girlfriend, i'm bored",
#    'Feel complete',
#    'Kill Bill',
#    'Chun Swae (feat. Swae Lee)',
#    'Pretty Little Birds (feat. Isaiah Rashad)',
#    'Luv Is Dro (feat. Static Major & Bryson Tiller)',
#    'Go There with You',
#    'B.S. (feat. H.E.R.)',
#    'Session 32',
#    'Passion',
#    'Not My Job',
#    'Juicy',
#    'The Worst',
#    '7 rings',
#    'Playing Games',
#    'On My Mama',
#    'Gun',
#    'Kiss Me More (feat. SZA)',
#    'Out Thë Way',
#    'Super Freaky Girl'],
#   'loved': ["we can't be friends (wait for your love)",
#    'i wish i hated you',
#    'supernatural',
#    'Saturn Returns Interlude',
#    'Moment 4 Life',
#    'imperfect for you',
#    'the boy is mine',
#    'eternal sunshine',
#    "don't wanna break up again",
#    'bye',
#    'intro (end of the world)',
#    'true story',
#    'FYS',
#    '100% (feat. Tony Sunshine) (feat. Tony Sunshine)',
#    'Rich N Turnt',
#    'Class of 2013',
#    'DTM (Diamond Boy)',
#    'saturn',
#    'One of Your Girls',
#    'Fallen Angel',
#    'Looking For The Hoes (Ain’t My Fault)',
#    'U Should Know',
#    'nothing changë',
#    'Bought The Earth',
#    'Whatever She Wants',
#    'Hardcore',
#    'Nothing Easy to Please',
#    'Don’t Matter To Me (with Michael Jackson)',
#    'TALKING / ONCE AGAIN',
#    "Feelings Don't Lie",
#    'The Remorse',
#    'Motives',
#    "Cece's Interlude",
#    'The Calm',
#    '5 Am in Toronto',
#    '4PM in Calabasas',
#    '30 for 30 Freestyle',
#    'Stronger Than You (feat. Estelle)',
#    'Lifestyle',
#    'Pink Dolphin Sunset (feat. Tee)',
#    'i',
#    'Currents',
#    'Freedom Interlude',
#    'War 1',
#    'Lust for Life',
#    'Laser Lights',
#    'Unforgettable',
#    'Heaven Can Wait',
#    'My Place',
#    'Tomioka (with Flo Milli) - Remix']},
#  'Sandman099': {'top_50': ['Bacon Pancakes (feat. John DiMaggio)',
#    'THE BADDEST',
#    'MORE',
#    'VILLAIN',
#    'DRUM GO DUM',
#    "I'LL SHOW YOU",
#    'Feather (feat. Cise Starr & Akin from Cyne)',
#    'POP/STARS',
#    'All The Things She Said',
#    '乱舞のメロディ',
#    "I'm Just Your Problem (feat. Olivia Olson)",
#    'Chase',
#    'XS',
#    'Reflection Eternal',
#    'LOST IN PARADISE',
#    'sameolemeek',
#    'Blessing It -remix (feat. Substantial & Pase Rock from Five Deez)',
#    'Danger Room (feat. DJ Zo)',
#    'Intro',
#    'Quarantine (feat. AXELBLOODYAXEL)',
#    'The Point (feat. DJ Zo)',
#    '新時代 - ウタ from ONE PIECE FILM RED',
#    'III. Telegraph Ave. ("Oakland" by Lloyd)',
#    "SHE'S FINE",
#    'SEE U LATER',
#    'Forever Young',
#    'DDU-DU DDU-DU',
#    'Ordinary Joe (feat. Terry Callier)',
#    'REALLY',
#    'Black Skinhead',
#    'Eclipse (feat. Substantial)',
#    'Ice Cream (with Selena Gomez)',
#    'Brand New World',
#    'Luv(sic.) Pt3 (feat. Shing02)',
#    'The Heart Part 5',
#    'D-tecnoLife',
#    'Blockbuster Night Part 1',
#    'City Lights (feat. Pase Rock & Substantial)',
#    'How You Like That',
#    'The Sign (feat. Pase Rock)',
#    'Jesus Shuttlesworth',
#    'Music Is Mine',
#    'On Sight',
#    'Think Different (feat. Substantial)',
#    'Crazy Noisy Bizarre Town',
#    'STAND PROUD',
#    'I Am a God',
#    'Lady Brown (feat. Cise Starr from CYNE)',
#    'Funny How? (feat. Jay Park)',
#    'Levitating (feat. DaBaby)'],
#   'loved': ['Bow Bow Bow (F My Baby Mama) (feat. Chief Keef)',
#    'Big Man With a Gun',
#    'Kill the Poor',
#    'Holiday in Cambodia',
#    'Oh, Wait...',
#    'New Age Crisis',
#    'this is NOwhere',
#    'S!CK',
#    'Starry Lights',
#    'Flip Da Style',
#    'Day One',
#    'Thick',
#    'Da Enemy',
#    'ordinary things (feat. Nonna)',
#    'imperfect for you',
#    'i wish i hated you',
#    "we can't be friends (wait for your love)",
#    'yes, and?',
#    'true story',
#    'the boy is mine',
#    'supernatural',
#    'eternal sunshine',
#    "don't wanna break up again",
#    'Saturn Returns Interlude',
#    'bye',
#    'intro (end of the world)',
#    "Don't Get Lost in Heaven",
#    'Demon Days',
#    "Fire Coming Out of the Monkey's Head",
#    'All Alone',
#    'White Light',
#    'Every Planet We Reach Is Dead',
#    'El Mañana',
#    'O Green World',
#    'Dirty Harry',
#    'Kids With Guns',
#    'Intro',
#    'Last Living Souls',
#    'Epoch',
#    'dowop',
#    'Gateways',
#    'Son Gohan and Demon King Piccolo',
#    'Romantikku Ageru Yo',
#    'Fear Unfelt Before',
#    'Come Out, Incredible ZENKAI Power!',
#    'PAT ME DOWN',
#    'AKIRA - VF3',
#    'VANESSA - VF4',
#    'LION - VF3',
#    'PAI - VF3']},
#  'ryxthree': {'top_50': ['Young Robot',
#    'Three Wishes',
#    'We Own the Night',
#    'Man of the Year',
#    'Carve',
#    'Say Hi',
#    'Turbulent',
#    'Lyrics Lie',
#    'Doom Days',
#    'you should see me in a crown',
#    'Prisoner',
#    'Inspire the Liars',
#    'Something New',
#    '[Reboot]',
#    "Strawberry's Wake",
#    'Magnetic',
#    'Stroke God, Millionaire',
#    'Chucky vs. The Giant Tortoise',
#    'Born to Fail',
#    'Snow Globe',
#    'Liability',
#    'Son of Robot',
#    'Bunny Is a Rider',
#    'cardigan',
#    'Look What You Made Me Do',
#    'hoax',
#    'Synergy (feat. Rob Damiani)',
#    'Frozen One',
#    'Let Me Down Slowly',
#    'Dream Boy',
#    'High Definition',
#    "Wildest Dreams (Taylor's Version)",
#    'Watch What Happens Next',
#    'Deception',
#    '3%',
#    'Worst',
#    'Easy to Hate',
#    'Acceptance Speech',
#    'Everything',
#    'Violet!',
#    "So Hot You're Hurting My Feelings",
#    'Motion Sickness',
#    'The Archer',
#    'mirrorball',
#    'I Think He Knows',
#    'One in a Million',
#    'Flossie Dickey Bounce',
#    'Moon Song',
#    'Punisher',
#    'gold rush'],
#   'loved': ['Only Acting',
#    '君のように',
#    'Careless Whisper',
#    'Excess',
#    "Haunted (Taylor's Version)",
#    'The Chauffeur',
#    'Michelangelo',
#    'Swim Back',
#    'Blister Box',
#    'Right Through Me',
#    '•.¸.•SECOND♥LIFE•.¸.•',
#    'Thick_flowy_glowy_sparkly_stingy_pain.mpeg',
#    'Every Night My Teeth Are Falling Out',
#    'Bitch Bites Dog',
#    'Debra',
#    'Frou-Frou Foxes in Midsummer Fires',
#    'Only If You Want It',
#    'Chateau Lobby #4 (in C for Two Virgins)',
#    'Sweet Dreams (Are Made of This) - Remastered',
#    "Maxim's I",
#    'Very Online Guy',
#    'THE SIX',
#    'Still',
#    'Clean',
#    'I Feel Alive',
#    'Heart Attack (츄)',
#    'Meow Meow Lullaby',
#    "Soon-to-Be Innocent Fun/Let's See",
#    'Chimacum Rain',
#    'Glow Worms',
#    'Die Another Day',
#    'Give Me Love',
#    'What I Want',
#    'Unholy Affliction',
#    'Following Eyes',
#    'King Park',
#    'Numb',
#    '33 “GOD”',
#    'Child Psychology',
#    'New York',
#    'Walking In The Cemetery',
#    'Quicksand',
#    'ACTION',
#    'Hurt',
#    'Waltz #2 (XO)',
#    'Ch-Ching',
#    'Crying in Public',
#    'Everything',
#    'Sick',
#    'Domino']},
#  'thy_koosk': {'top_50': ['Sleepyhead',
#    'Måneblôt',
#    'Neighborhood #2 (Laika)',
#    'Kalyna',
#    'Community Pleading',
#    'Fager som en ros',
#    'Control',
#    'Green Trill Zone',
#    'Fulenn',
#    'Bear Creek',
#    'Судно (Борис Рижий)',
#    'Hope',
#    'Angel of Darkness',
#    'Draw Down the Moon',
#    'AFFLUENZA',
#    'Every Other Freckle',
#    'Pantherbeat',
#    'Konyali',
#    'Thru and Thru',
#    'hand crushed by a mallet (Remix) [feat. Fall Out Boy, Craig Owens, Nicole Dollanganger]',
#    'Southern Sky',
#    'Mary on a Cross',
#    'Dari dari',
#    'Balaleen',
#    'Bobby',
#    'Bialystok',
#    'Sugar',
#    'Tu Tu Neurotic',
#    'Let It Happen',
#    'Neighborhood #3 (Power Out)',
#    'Pools',
#    'Ciężar',
#    'Me and Michael',
#    'X',
#    'Into The Dark',
#    'Caramelldansen',
#    'This God is Dead',
#    'The Ballad of Calamity James',
#    'Rydeen',
#    'Gretel',
#    'Vicious Pastimes',
#    'Ladyflash',
#    'The Journey',
#    'Runner',
#    'Grand Paradise',
#    'Sluntseto Trepti',
#    'Blue Sunday',
#    'Sweetness',
#    'Monster',
#    'DOMINATRIX'],
#   'loved': ['Treehouse',
#    'Prophecy',
#    'Oblivion',
#    'Stereo',
#    'Weaponz',
#    'Go With The Flow',
#    'MURDER (feat. Code:Pandorum)',
#    'Car',
#    'Darkbeat',
#    'Words Are Failing',
#    'Wheel of Time',
#    'Firefighter',
#    'Angel',
#    'Dansez',
#    'Tagasi Me',
#    'Teel voorusesse',
#    'uMlando',
#    'Junktime',
#    'Apaz',
#    '…Pelas Costuras',
#    'The Voice of the Wind',
#    'Hello Hallelujah',
#    'Yung Hearts Bleed Free',
#    'Worship The Internet',
#    'Promised You a Miracle',
#    'The Love Parade',
#    'Time Trials',
#    'Makes Me Violent',
#    'плавить',
#    'Astraeus',
#    'Soul Is The Price',
#    'As Above, So Below',
#    'Roll & Tumble',
#    "Can't Hold Us",
#    'Unholy',
#    'Bird Set Free',
#    'God Rest Ye Merry Gentlemen',
#    'Toxic',
#    'Police & Thieves - Remastered',
#    "You Don't Get Me High Anymore",
#    'Ymir II',
#    'MK Nothing',
#    'cheerleader (ft. Waterparks)',
#    'Falling Illusions - Radio Edit',
#    'Tonada De Luna Llena',
#    'Get Out Of My House',
#    'Obsession',
#    'Tocka - Edit',
#    'Shayed Qousourak',
#    'Zbog tebe živim']},
#  'guywithaqmark': {'top_50': ['Kyoto',
#    'Fatalist Palmistry',
#    'Line Without A Hook',
#    'Settle Down',
#    'This December',
#    'Get Used to It',
#    'Savior Complex',
#    'Eraser',
# ...
#    'Lionsong',
#    'テリフリアメ',
#    'Get Got',
#    'El Anillo del Capitán Beto',
#    'Sad Pony Guerrilla Girl',
#    'Windowlicker',
#    'Sleeping In A Jar',
#    'Superchería',
#    'DM True',
#    'Meat Grinder',
#    'Rosemary',
#    'A Starosta, El Idiota',
#    'Ram On - Remastered 2012',
#    'Vitamin C',
#    'Que Ves El Cielo',
#    'Cantata De Puentes Amarillos',
#    'America',
#    'Brokeup',
#    'Tudo o Que Você Podia Ser',
#    'Peaches en Regalia',
#    'money machine',
#    'Old Friends',
#    'Avril 14th',
#    'Los Libros De La Buena Memoria',
#    'Todas Las Hojas Son Del Viento',
#    'April Come She Will',
#    'Por',
#    'Jóga',
#    '太陽さん',
#    'Harness',
#    'Tropical Hot Dog Night',
#    'Cementerio Club',
#    'Fingerbib',
#    'Fossil',
#    'Tonada De Luna Llena',
#    'Death With Dignity'],
#   'loved': []},
#  'warldron': {'top_50': ['2EM09_YAMASHITA',
#    'The Longest Day II',
#    'The Longest Day',
#    'The Longest Day III',
#    'Strategie "Yashima"',
#    'Bataille Decisive',
#    'Go!',
#    'Fade Into You',
#    'Little Dark Age',
#    'jupiter',
#    'Прощай навеки, последняя любовь',
#    'Premiere Manoeuvre',
#    "Nothing's Gonna Hurt You Baby",
#    'On Fire',
#    'Angela',
#    'Theme From PSB',
#    'Stranger',
#    'In Amber Clad',
#    'Spitfire',
#    'Excitable Boy - 2007 Remaster',
#    'Dress Up in You',
#    'Far From Any Road',
#    'The Night We Met (feat. Phoebe Bridgers)',
#    'Flowers In December',
#    'Halah',
#    'Waves',
#    'On Sight',
#    '今日の日はさようなら-Tribute to "Sound of Music"',
#    'The Boy With the Arab Strap',
#    'stranger',
#    'Christmas Island',
#    'Video Killed the Radio Star',
#    'Look on Down From the Bridge',
#    'Common People',
#    'I Just Threw Out the Love of My Dreams',
#    'Wild Roses',
#    'Sit Down',
#    'Blue Flower',
#    'Plainsong - 2010 Remaster',
#    'The Red Army Is the Strongest',
#    'Contact',
#    'A Dream of You and Me',
#    'Les Champs-Elysées',
#    'Cold (feat. Dana Jean Phoenix)',
#    'She Works Out Too Much',
#    'Yorktown (The World Turned Upside Down)',
#    'Arms Length',
#    '2EM38_F02',
#    'All Along the Watchtower',
#    'Be My Angel'],
#   'loved': ['bury a friend',
#    'First Strike 2010 (Sebastian Brandt Remix)',
#    'I REALLY WANT TO STAY AT YOUR HOUSE by Rosa Walton & Hallie Coggins',
#    'Perturbator Death Squad Extended',
#    'La vie en rose',
#    'MGMT - Little Dark Age (TikTok Remix) Lyrics',
#    '𝐍𝐢𝐠𝐡𝐭𝐜𝐚𝐥𝐥 (𝐬𝐥𝐨𝐰𝐞𝐝 + 𝐫𝐞𝐯𝐞𝐫𝐛)',
#    'Southern Nights',
#    "Halo (feat. Martin O'Donnell, Michael Salvatori)",
#    'Fainted (Slowed)',
#    'synthwave remix)',
#    'The Perfect Girl',
#    'Lost Kitten',
#    'old west storytelling background (tunepocket music library)',
#    'Stereo Love',
#    'A Cup Of Liber-Tea',
#    'Atlas',
#    'Evacuate the Dancefloor',
#    'The Perfect Girl (AGTHA REMIX)',
#    'Crystal Castles - Kept (AGTHA REMIX)',
#    'Half-Life 2 - Something Secret Steers Us (remix)',
#    'HELLDIVERS 2']},
#  'JonathanHalen': {'top_50': ['Like a Rolling Stone',
#    'A Case of You',
#    'A Change Is Gonna Come',
#    "What's Going On",
#    'Acknowledgement',
#    'So What',
#    'Stairway to Heaven',
#    'Purple Rain',
#    'A Day in the Life',
#    'When Doves Cry',
#    'Bohemian Rhapsody',
#    'Imagine',
#    'Smells Like Teen Spirit',
#    'With or Without You',
#    'Pursuance',
#    'Jeremy',
#    'Good Vibrations',
#    'Resolution',
#    'Beat It',
#    'Suspicious Minds',
#    'Runaway',
#    'Psalm',
#    'Jungleland',
#    'God Only Knows',
#    'Johnny B. Goode',
#    "(Sittin' On) The Dock of the Bay",
#    'Welcome to the Jungle',
#    'Superstition',
#    'Karma Police',
#    'Freddie Freeloader',
#    'Nothing Compares 2 U',
#    'Lithium',
#    'Hallelujah',
#    'Teen Age Riot',
#    'The Card Cheat',
#    'Flamenco Sketches',
#    'Live to Tell',
#    "Don't Look Back in Anger",
#    'Bridge Over Troubled Water',
#    'Seven Nation Army',
#    'Purple Haze',
#    'Light My Fire',
#    'Angry Chair',
#    'All Blues',
#    'The Great Gig in the Sky',
#    "I Can't Make You Love Me",
#    'Doo Wop (That Thing)',
#    'Formation',
#    'Gimme Shelter',
#    'It Takes a Lot to Laugh, It Takes a Train to Cry'],
#   'loved': ["It's Too Late",
#    "I Can't Make You Love Me",
#    'Untitled (How Does It Feel)',
#    'Really Love',
#    'Wholy Holy',
#    'One Nation Under a Groove',
#    'Everyday People',
#    'Family Affair',
#    'Acknowledgement',
#    'Resolution',
#    'Psalm',
#    'Pursuance',
#    'Naima',
#    'Twenty Four Hours',
#    'Teen Age Riot',
#    "I've Been Loving You Too Long",
#    'Simple Twist of Fate',
#    'Blue',
#    'Big Yellow Taxi',
#    'Ring of Fire',
#    'Chain of Fools',
#    'Spanish Key',
#    'The Space Travelers Lullaby',
#    'Tightrope',
#    'Make Me Feel',
#    'Rebel Without a Pause',
#    "What's Happening Brother",
#    "Heart of the City (Ain't No Love)",
#    'Human Behaviour',
#    'Big Time Sensuality',
#    'Army of Me',
#    'Sunday Morning',
#    'Heroin',
#    "I'm Waiting for the Man",
#    'The Boy in the Bubble',
#    'Graceland',
#    'Jesus Walks',
#    'Little Red Corvette',
#    'A Day in the Life',
#    'Help Me',
#    'A Case of You',
#    'River',
#    'The Last Time I Saw Richard',
#    'You Still Believe in Me',
#    'Think',
#    'I Never Loved a Man (the Way I Love You)',
#    'Runaway',
#    'APESHIT',
#    'All Blues',
#    'Blue in Green']},
#  'thesleepycloud': {'top_50': ['Grins',
#    'Everything Is Embarrassing',
#    'Hold It Against Me',
#    'One',
#    'Happy',
#    'Breakdown (feat. Krayzie Bone & Wish Bone)',
#    "You're Not the One",
#    'No Ordinary Love',
#    'Million Dollar Man',
#    'Painter (Valentine)',
#    'Station',
#    'Starring Role',
#    'Treasure Island',
#    'Wildest Moments',
#    'So Far Away',
#    'Froot',
#    "You're the One",
#    'Fourth of July',
#    'Honey',
#    'Misty',
#    'Bliss',
#    'Only Yesterday',
#    'Living Dead',
#    'What I Like',
#    'Yayo',
#    'Bewitched',
#    '108',
#    'The Good Life',
#    'Onde Anda Você ?',
#    'Bullet Proof Soul',
#    'Teen Heat',
#    'The Art of Letting Go',
#    'Nobody but You',
#    'GTFO',
#    'This Is Always',
#    'Hallucination',
#    'Summertime Sadness',
#    'Lost in My Bedroom',
#    'Red Lips',
#    'Sad Dream',
#    'Radio',
#    'Cherish the Day',
#    'Video Games',
#    'Bad Girls (Verdine version)',
#    'As You Are',
#    'The Distance (feat. Ty Dolla $ign)',
#    'Love in High Places',
#    'The Chase',
#    'Caos',
#    'Love Me For What I Am'],
#   'loved': ['Hrs & Hrs',
#    'See You Again',
#    'Russian Roulette',
#    'Feeling Good',
#    "You Don't Know My Name",
#    'This Is What Makes Us Girls',
#    'Off to the Races',
#    'Harleys in Hawaii',
#    'HEATED',
#    'Outside',
#    'Paper Bag',
#    'Problem',
#    'LIKE I WOULD',
#    'Angel of the Morning',
#    "L'Amour Toujours",
#    'Disparate Youth',
#    'All in Love Is Fair',
#    'The Lady in My Life',
#    "That's the Way Love Goes",
#    'Domestica',
#    'Exist For Love',
#    'Glad to Be Unhappy',
#    'One Evening',
#    'House of Love',
#    'Me, Myself and I',
#    'Break the Ice',
#    'One by One',
#    'Believe',
#    "It's a Heartache",
#    'Love song',
#    'At My Heels',
#    'In My Bed',
#    'Remember the Time',
#    'In the Closet',
#    'Jam',
#    'Break of Dawn',
#    'Birds of Prey',
#    'This Is Always',
#    'Get Free',
#    'Next Lifetime',
#    'A No No',
#    "I Can Dream, Can't I?",
#    'Love Me For What I Am',
#    'Regret',
#    'Love Drought',
#    'Lower the Tone',
#    'Outro Sim',
#    "What's Going On",
#    'Mr. Guder',
#    'Hurting Each Other']},
#  'xdsocky': {'top_50': ['Everything Counts',
#    'Enjoy the Silence',
#    'Race for the Prize',
#    "Say It Ain't So",
#    'People Are People',
#    'Such Great Heights',
#    'The District Sleeps Alone Tonight',
#    'Undone - The Sweater Song',
#    "Get Me Away from Here, I'm Dying",
#    'Master and Servant',
#    'The Good Life',
#    'Wild Horses',
#    'Policy of Truth',
#    'Fight Test',
#    'Missing',
#    'We Let The Stars Go',
#    'When Love Breaks Down',
#    'Strangelove',
#    'Never Let Me Down Again',
#    'Feeling Yourself Disintegrate',
#    'Rebellion (Lies)',
#    'Never Meant',
#    'Shake the Disease',
#    'Bonny',
#    'No Surprises',
#    'My Name Is Jonas',
#    'Halo',
#    'World in My Eyes',
#    'Casimir Pulaski Day',
#    'Stripped',
#    'Appetite',
#    'All My Favorite Songs',
#    "The King of Rock 'N' Roll",
#    'In Your Room',
#    'Personal Jesus',
#    'Carnival 2000',
#    'I Want Wind to Blow',
#    'Only in Dreams',
#    'Running Up That Hill (A Deal with God)',
#    'Cars And Girls',
#    'Precious',
#    'Your Arms Around Me',
#    'Buddy Holly',
#    "Just Can't Get Enough",
#    'Holland, 1945',
#    'Hoppípolla',
#    'Runner',
#    'Blasphemous Rumours',
#    'Walking in My Shoes',
#    'Neighborhood #1 (Tunnels)'],
#   'loved': ["I'm Leaving You Because I Don't Love You",
#    'eternal sunshine',
#    'bye',
#    "we can't be friends (wait for your love)",
#    'The World Is Our ___',
#    'When I Was Done Dying',
#    'The World at Large',
#    'Clearest Blue',
#    'Lies',
#    'Recover',
#    'We Sink',
#    'The Mother We Share',
#    'Capricorn',
#    'Gen-X Cops',
#    'Exile Vilify',
#    'This Fffire',
#    'C',
#    '孤独の発明',
#    'Fake Empire',
#    'Take Ecstasy With Me',
#    'Wild Guess',
#    'Snow and Lights',
#    'Remember Me as a Time of Day',
#    'Houdini',
#    'An Illusion',
#    'We Make Hits',
#    'Fizzy Fish',
#    'Which Will',
#    'Parasite',
#    'Free Ride',
#    'Like Antennas To Heaven…',
#    'Holy Mountains',
#    'Strangers',
#    'Coma',
#    'The Shoe Fits',
#    'UNDER My Skin',
#    'PRETTY PRIVILEGE',
#    'From My Pillow',
#    'Working On My Dreams',
#    'Everybody Wants To Love You',
#    'By Your Side',
#    'Aftermath',
#    'Ocean Breathes Salty',
#    'Bukowski',
#    'Stairway to Heaven',
#    'Untitled #9 - Smáskífa 1',
#    'God, or Whatever You Call It',
#    'Butterfly Net (feat. Weyes Blood)',
#    'You Wanted a Hit',
#    'yes, and?']},
#  'digitalgoober': {'top_50': ['Wallace',
#    'Night of the Swallow',
#    'Voodoo Child (Slight Return)',
#    'Wuthering Heights',
#    'Not About Love',
#    'Come as You Are',
#    'In Bloom',
#    'Leave It Open',
#    'Mama',
#    'Lovefool',
#    'Some Might Say',
#    'Little Wing',
#    'Heavy Metal and Reflective',
#    'Comfortably Numb',
#    'Intro',
#    'Better Version of Me',
#    "Don't Look Back in Anger",
#    'Morning Glory',
#    'The Sound of Silence',
#    'Cooking Up Something Good',
#    'Girls & Boys',
#    'Pull Out the Pin',
#    'Ode to Viceroy',
#    'Self Control',
#    'Easy',
#    'Monkey & Bear',
#    'sunkissed',
#    'Luxury',
#    'Row Jimmy',
#    'Flashing Lights',
#    'Sat in Your Lap',
#    'The Infant Kiss',
#    '212 (feat. Lazy Jay)',
#    'MY JEAN',
#    'Norwegian Wood (This Bird Has Flown)',
#    'Lucifer',
#    'Edge of Seventeen',
#    'Eleanor Rigby',
#    'While My Guitar Gently Weeps',
#    'The National Anthem',
#    'Suspended in Gaffa',
#    'You Can Sense It',
#    'VEGAS',
#    'Bad Penny',
#    'Flashing Lights (ft. Dwele)',
#    'Champagne Supernova',
#    'Supersonic',
#    'If You Know You Know',
#    'Music Sounds Better With You',
#    'Love Foundation'],
#   'loved': ['Crazy on You',
#    'Dreams',
#    'Gold Dust Woman',
#    'The Chain',
#    'Hidden Place',
#    'Wake Up',
#    'Niggas in Paris',
#    'The Red Shoes',
#    'Maps',
#    'Dissolve Me',
#    'Something Good',
#    'Edge of Seventeen',
#    'Yellow Submarine',
#    'Fade to Black',
#    'Vienna',
#    'Policy of Truth',
#    "Don't Speak",
#    'Time',
#    'Smooth Criminal',
#    'Us and Them',
#    'Sheep',
#    'Mariners Apartment Complex',
#    'Turn the Beat Around',
#    'Rushes To',
#    'Doo Wop (That Thing)',
#    'Chamber of Reflection',
#    'Idioteque',
#    'Baby Birch',
#    'How to Disappear Completely',
#    'XXX',
#    'The Queen Is Dead',
#    "Isn't She Lovely",
#    'Ghost Town',
#    'Brooklyn Baby',
#    "Movin' On Up",
#    "Rudie Can't Fail",
#    'Bridges and Balloons',
#    'Jesus Children of America',
#    'Kingfisher',
#    'Dambala',
#    'JESUS',
#    'Kings',
#    'KRS-One',
#    'Smells Like Teen Spirit',
#    'Graduation Day',
#    'Two Words (Feat. Mos Def, Freeway & The Boys Choir of Harlem)',
#    'Stairway to Heaven',
#    'Devil in a New Dress (feat. Rick Ross)',
#    'Sprawl II (Mountains Beyond Mountains)',
#    'The Sound of Silence']},
#  'x_TMMC': {'top_50': ["Can't Let Go",
#    'I Want You',
#    'No Scrubs',
#    'Rock with U',
#    'Try Again',
#    'Remember the Time',
#    'How You Like That',
#    'A.D.H.D',
#    "That's the Way Love Goes",
#    'Butterflies',
#    'Prisoner',
#    'Smooth Operator',
#    'All for You',
#    'Why Should I Be Sad',
#    'Alone in Love',
#    'Call on Me',
#    'Sucka for Love',
#    'APESHIT',
#    'So Excited',
#    'We Need a Resolution',
#    "Doesn't Really Matter",
#    'Rock with You',
#    'Really Doe',
#    'If',
#    'Talk About Our Love (feat. Kanye West)',
#    'Come Back to Me',
#    'Creep',
#    "Un-Thinkable (I'm Ready)",
#    'Make Me',
#    'Someone to Call My Lover',
#    "All Nite (Don't Stop)",
#    'Foolish',
#    'Heaven Can Wait',
#    'Alejandro',
#    'Melt Away',
#    'Hold Back the Tears',
#    'Paradise',
#    'On & On',
#    'Smooth Criminal',
#    'Fu-Gee-La',
#    'Stainless',
#    "You Don't Know My Name",
#    'Dance or Die (feat. Saul Williams)',
#    'The Way You Make Me Feel',
#    'Sunburn',
#    'Strawberry Bounce',
#    'The Sweetest Taboo',
#    'Anytime You Need a Friend',
#    'Pour Out A Little Liquor',
#    'We Belong Together'],
#   'loved': ['Toilet Tisha',
#    'Red Velvet',
#    '4 Better Or 4 Worse',
#    "I'm That Type Of Nigga",
#    'Late',
#    'Drive Slow',
#    "Heard 'Em Say",
#    'I Wonder',
#    "Runnin'",
#    'Electric',
#    'Pieces',
#    'How (feat. Roddy Ricch)',
#    'Power Of A Woman',
#    'Trying',
#    'Beg For It',
#    'Soldier',
#    'Feels Like',
#    "Didn't Say (feat. Latto)",
#    'Not Another Love Song',
#    'If I Never See Your Face Again',
#    'Figure It Out',
#    'Not Falling Apart',
#    'What Are We Doing',
#    'Obsession',
#    'The Air That I Breathe',
#    'Hands All Over',
#    'Stutter',
#    'Message To The Fans (Skit)',
#    'Never Gonna Leave This Bed',
#    "I Can't Lie",
#    'Give a Little More',
#    'Get Back in My Life',
#    'Into You',
#    'Big Subwoofer',
#    'Misery',
#    'Yeah Glo!',
#    'BURN',
#    'DO IT',
#    'PAID',
#    'Big',
#    'Luckiest Man',
#    'Iffy',
#    'Main Chick (Feat. Chris Brown)',
#    'A2Z',
#    'Fear (Single Version)',
#    'Average Joe',
#    'Barbed Wire',
#    'Siempre Hay Esperanza',
#    "St. Elmo's Fire",
#    'Monkey See-Monkey Do']},
#  'ctalbot4': {'top_50': ['N.Y. State of Mind',
#    'King Kunta',
#    'untitled 02 | 06.23.2014.',
#    'Devil in a New Dress',
#    'Off Da Zoinkys',
#    'N95',
#    'DNA.',
#    'Father Stretch My Hands Pt. 1',
#    'Guilt Trip',
#    'family ties (with Kendrick Lamar)',
#    'good kid',
#    'Two Words',
#    '4th Dimension',
#    'Blood on the Leaves',
#    'Heartless',
#    'No More Parties in LA',
#    'Street Lights',
#    'm.A.A.d city',
#    'Momma',
#    'Feel the Love',
#    "WHAT'S GOOD",
#    'New Slaves',
#    'Off the Grid',
#    'Alright',
#    'Silent Hill',
#    'With or Without You',
#    'Praise God',
#    'Backseat Freestyle',
#    'How Much a Dollar Cost',
#    'Heartless',
#    'Headlines',
#    'Renegade',
#    'So Appalled',
#    'The Blacker the Berry',
#    'Never Let Me Down',
#    'untitled 03 | 05.28.2013.',
#    "Life's a Bitch",
#    'November',
#    'Gorgeous',
#    'Hold My Liquor',
#    'Woods',
#    'Wicked Games',
#    "Who's Gonna Ride Your Wild Horses",
#    'Black Skinhead',
#    'Gone',
#    'I Am a God',
#    'Hard Piano',
#    'After Hours',
#    'Faith',
#    'Stay (Faraway, So Close!)'],
#   'loved': ['Rice & Gravy',
#    'Myth',
#    'Head Over Heels / Broken',
#    'White',
#    'Hometown Glory',
#    'Prayers for Rain',
#    'Nosetalgia',
#    'Alewife',
#    'So It Goes',
#    'Pound Cake / Paris Morton Music 2',
#    'Subterranean Homesick Alien',
#    'Try Me',
#    'Life of the Party (with André 3000)',
#    'Face to Face',
#    'Weird Fishes / Arpeggi',
#    'Buried Alive Interlude',
#    'DNA.',
#    'good kid',
#    'untitled 06 | 06.30.2014.',
#    'Crown',
#    'Kody Blu 31',
#    'The Tourist',
#    'The Heart Part 4',
#    'How Much a Dollar Cost',
#    'Money Trees',
#    'Pride (in the Name of Love)',
#    'untitled 02 | 06.23.2014.',
#    'Count Me Out',
#    '6 God',
#    'Mofo',
#    'family ties (with Kendrick Lamar)',
#    'Rejoice',
#    "What's the Use?",
#    'United in Grief',
#    'After Hours',
#    'Blinding Lights',
#    'Guilt Trip',
#    'Bullet the Blue Sky',
#    'Less Than Zero',
#    "Life's a Bitch",
#    'Renegade',
#    'All For Leyna',
#    'untitled 05 | 09.21.2014.',
#    'Ghost Town',
#    'Garden Shed (feat. Estelle)',
#    'For Sale? - Interlude',
#    'Good News',
#    'Family Business',
#    'Rainy Day',
#    'RoboCop']},
#  ...}

# %%
df = pd.read_excel('lastfm_users_songs.xlsx')
from ast import literal_eval
df['Liked Songs'] = df['Liked Songs'].apply(lambda x: [] if pd.isna(x) or x == "" else x)

def safe_eval(x):
    try:
        return literal_eval(x)
    except:
        return x

df['Liked Songs'] = df['Liked Songs'].apply(safe_eval)

num_rows_with_empty_liked_songs = df[df['Liked Songs'].apply(lambda x: len(x) == 0 if isinstance(x, list) else False)].shape[0]

print(num_rows_with_empty_liked_songs)
# Out:
# -2199
