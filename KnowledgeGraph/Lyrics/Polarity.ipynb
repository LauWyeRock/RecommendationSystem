# %%
import pandas as pd
songs = pd.read_excel('Eng_Lyrics_with_Profanity.xlsx')

# %%
test_10_rows=songs[:10]
test_10_rows
# Out:
#    Unnamed: 0                       track_name  \
# 0           0                          Diptick
# 1           1                    Street Lights
# 2           2                             Kato
# 3           3         HELP ME (with Dead Sara)
# 4           4                  Wanna B Ur Lovr
# 5           5             WHERE MAN KNOWS WANT
# 6           6                        Bongoloid
# 7           7             On Key - Audio Remix
# 8           8               Chop Chop, Goodbye
# 9           9  What We Need More of Is Science
#
#                                          artist_name  \
# 0                                     William Fields
# 1                                         Kanye West
# 2                                        The Aubreys
# 3                                        Demi Lovato
# 4                                "Weird Al" Yankovic
# 5                                          The Armed
# 6                                             Goto80
# 7                                            Limewax
# 8  I Wrote Haikus About Cannibalism in Your Yearbook
# 9                                         MC Hawking
#
#                                               lyrics  profanity_densv  \
# 0  \nalarmed for the condition in which the kingd...         0.000166
# 1  let me know\ndo i still got time to grow\nthin...         0.000000
# 2  older i know but can i still be bathed by you\...         0.007576
# 3  adrianne lenker  dragon eyes\ndan bull  squadr...         0.001706
# 4  but do you mind if i check you out\ni like you...         0.000000
# 5  i cant fall asleep\na jukebox that only has on...         0.000000
# 6                                                NaN              NaN
# 7  one two one two\n\nadam bainbridge\thello hi\n...         0.003273
# 8                                                NaN              NaN
# 9  im a disciple of science\ni know the universe ...         0.023179
#
#               top_profanity_cat
# 0        other / general insult
# 1                           NaN
# 2  sexual anatomy / sexual acts
# 3  sexual anatomy / sexual acts
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7     bodily fluids / excrement
# 8                           NaN
# 9     bodily fluids / excrement

# %%
test_10_rows
# Out:
#    Unnamed: 0                       track_name  \
# 0           0                          Diptick
# 1           1                    Street Lights
# 2           2                             Kato
# 3           3         HELP ME (with Dead Sara)
# 4           4                  Wanna B Ur Lovr
# 5           5             WHERE MAN KNOWS WANT
# 6           6                        Bongoloid
# 7           7             On Key - Audio Remix
# 8           8               Chop Chop, Goodbye
# 9           9  What We Need More of Is Science
#
#                                          artist_name  \
# 0                                     William Fields
# 1                                         Kanye West
# 2                                        The Aubreys
# 3                                        Demi Lovato
# 4                                "Weird Al" Yankovic
# 5                                          The Armed
# 6                                             Goto80
# 7                                            Limewax
# 8  I Wrote Haikus About Cannibalism in Your Yearbook
# 9                                         MC Hawking
#
#                                               lyrics  profanity_densv  \
# 0  \nalarmed for the condition in which the kingd...         0.000166
# 1  let me know\ndo i still got time to grow\nthin...         0.000000
# 2  older i know but can i still be bathed by you\...         0.007576
# 3  adrianne lenker  dragon eyes\ndan bull  squadr...         0.001706
# 4  but do you mind if i check you out\ni like you...         0.000000
# 5  i cant fall asleep\na jukebox that only has on...         0.000000
# 6                                                NaN              NaN
# 7  one two one two\n\nadam bainbridge\thello hi\n...         0.003273
# 8                                                NaN              NaN
# 9  im a disciple of science\ni know the universe ...         0.023179
#
#               top_profanity_cat polarity subjectivity
# 0        other / general insult     None         None
# 1                           NaN     None         None
# 2  sexual anatomy / sexual acts     None         None
# 3  sexual anatomy / sexual acts     None         None
# 4                           NaN     None         None
# 5                           NaN     None         None
# 6                           NaN     None         None
# 7     bodily fluids / excrement     None         None
# 8                           NaN     None         None
# 9     bodily fluids / excrement     None         None

# %%
songs
# Out:
#         Unnamed: 0                                         track_name  \
# 0                0                                            Diptick
# 1                1                                      Street Lights
# 2                2                                               Kato
# 3                3                           HELP ME (with Dead Sara)
# 4                4                                    Wanna B Ur Lovr
# ...            ...                                                ...
# 288248      288248                             Here Comes Sweet Death
# 288249      288249                                  Anesthetic Vapors
# 288250      288250                                      A Human Touch
# 288251      288251                                           Stubborn
# 288252      288252  Cocaine Blues - Live at Folsom State Prison, F...
#
#                 artist_name  \
# 0            William Fields
# 1                Kanye West
# 2               The Aubreys
# 3               Demi Lovato
# 4       "Weird Al" Yankovic
# ...                     ...
# 288248             Midnight
# 288249            Goatpenis
# 288250       Jackson Browne
# 288251          My Fictions
# 288252          Johnny Cash
#
#                                                    lyrics  profanity_densv  \
# 0       \nalarmed for the condition in which the kingd...         0.000166
# 1       let me know\ndo i still got time to grow\nthin...         0.000000
# 2       older i know but can i still be bathed by you\...         0.007576
# 3       adrianne lenker  dragon eyes\ndan bull  squadr...         0.001706
# 4       but do you mind if i check you out\ni like you...         0.000000
# ...                                                   ...              ...
# 288248  theyre of no use at all\nswallow your wine bit...         0.000000
# 288249                                                NaN              NaN
# 288250  you can call it a decision\ni say its how were...         0.000000
# 288251                                                NaN              NaN
# 288252                                                NaN              NaN
#
#                    top_profanity_cat polarity subjectivity
# 0             other / general insult     None         None
# 1                                NaN     None         None
# 2       sexual anatomy / sexual acts     None         None
# 3       sexual anatomy / sexual acts     None         None
# 4                                NaN     None         None
# ...                              ...      ...          ...
# 288248                           NaN     None         None
# 288249                           NaN     None         None
# 288250                           NaN     None         None
# 288251                           NaN     None         None
# 288252                           NaN     None         None
#
# [288253 rows x 8 columns]

# %%
from textblob import TextBlob
df = songs

def analyze_sentiment(lyrics):
    blob = TextBlob(lyrics)
    return blob.sentiment

for index,row in df.iterrows():
    if row['polarity'] != None and row['subjectivity'] != None:
        continue
    lyrics = row['lyrics']
    sentiment = analyze_sentiment(str(lyrics))
    if sentiment.polarity:
        df.at[index, 'polarity'] = round(sentiment.polarity, 3)
    if sentiment.subjectivity:
        df.at[index, 'subjectivity'] = round(sentiment.subjectivity, 3)

df.head()

# Analyze sentiment of preprocessed lyrics
#sentiment = analyze_sentiment(lyrics)
#print(f"Sentiment polarity: {sentiment.polarity}, Sentiment subjectivity: {sentiment.subjectivity}")

# Polarity is a float within the range [-1.0, 1.0] where 1 means positive statement and -1 means a negative statement.
#Subjectivity quantifies the amount of personal opinion and factual information contained in the text. The higher subjectivity means that the text contains personal opinion rather than factual information.
# Out:
#    Unnamed: 0                track_name          artist_name  \
# 0           0                   Diptick       William Fields
# 1           1             Street Lights           Kanye West
# 2           2                      Kato          The Aubreys
# 3           3  HELP ME (with Dead Sara)          Demi Lovato
# 4           4           Wanna B Ur Lovr  "Weird Al" Yankovic
#
#                                               lyrics  profanity_densv  \
# 0  \nalarmed for the condition in which the kingd...         0.000166
# 1  let me know\ndo i still got time to grow\nthin...         0.000000
# 2  older i know but can i still be bathed by you\...         0.007576
# 3  adrianne lenker  dragon eyes\ndan bull  squadr...         0.001706
# 4  but do you mind if i check you out\ni like you...         0.000000
#
#               top_profanity_cat polarity subjectivity
# 0        other / general insult    0.147        0.514
# 1                           NaN    -0.35          0.9
# 2  sexual anatomy / sexual acts   -0.072        0.553
# 3  sexual anatomy / sexual acts    0.067        0.502
# 4                           NaN    0.233        0.639

# %%
import lyricsgenius
import requests
genius_client_id = "wZZ2RWc5mqp-5Pbz2W1rQJWE8LQ3pFBrb1Hw5_AOqgybq28mt7kjdjcG4zktCNbO"
genius_client_secret = "PefqBJHor_muDgTutGlaXXaxmzsI7TQCps9FQ3FwkUTT0WJIT3s0A5YA9mnFbfp_-CBhQF7b0omgE8kaM3dJ3w"
genius_access_token = "NUHHVpwnmbDYUYw8Padu0gQeHvYN4OsKYtE2MKNUpBUI6yR-xZXKY6S5NvCnFbiP"


genius = lyricsgenius.Genius("genius_access_token")

def get_lyrics(song_title, artist_name):
    try:
        song = genius.search_song(song_title, artist_name)
        if song:
            return song.lyrics
    except requests.exceptions.Timeout as e:
        # Handle timeout exceptions here
        print(f"Request timed out: {e}")
    except requests.exceptions.HTTPError as e:
        # Handle HTTP errors here
        print(f"HTTP error occurred: {e}")
    except requests.exceptions.ConnectionError as e:
        # Handle connection errors here
        print(f"Connection error occurred: {e}")
    except requests.exceptions.RequestException as e:
        # Handle any other request exceptions here
        print(f"An error occurred during the request: {e}")
    return None

# Example usage
lyrics = get_lyrics("Young and Beautifu", "Lana Del Rey")
print(lyrics)
# Out:
# Searching for "Young and Beautifu" by Lana Del Rey...
# Done.
# 156 ContributorsTranslationsFrançaisEspañolΕλληνικάفارسیNederlandsItalianoPortuguêsTürkçeDansk日本語DeutschYoung and Beautiful Lyrics[Verse 1]
# I've seen the world, done it all
# Had my cake now
# Diamonds, brilliant, and Bel Air now
# Hot summer nights, mid-July
# When you and I were forever wild
# The crazy days, city lights
# The way you'd play with me like a child
#
# [Chorus]
# Will you still love me when I'm no longer young and beautiful?
# Will you still love me when I got nothing but my aching soul?
# I know you will, I know you will, I know that you will
# Will you still love me when I'm no longer beautiful?
#
# [Verse 2]
# I've seen the world, lit it up as my stage now
# Channeling angels in the new age now
# Hot summer days, rock and roll
# The way you'd play for me at your show
# And all the ways I got to know
# Your pretty face and electric soul
#
# [Chorus]
# Will you still love me when I'm no longer young and beautiful?
# Will you still love me when I got nothing but my aching soul?
# I know you will, I know you will, I know that you will
# Will you still love me when I'm no longer beautiful?
# See Lana Del Rey LiveGet tickets as low as $95You might also like[Bridge]
# Dear Lord, when I get to Heaven
# Please, let me bring my man
# When he comes, tell me that You'll let him in
# Father, tell me if You can
# All that grace, all that body
# All that face makes me wanna party
# He's my sun, he makes me shine like diamonds
#
# [Chorus]
# Will you still love me when I'm no longer young and beautiful?
# Will you still love me when I got nothin' but my aching soul?
# I know you will, I know you will, I know that you will
# Will you still love me when I'm no longer beautiful?
#
# [Outro]
# Will you still love me when I'm no longer beautiful?
# Will you still love me when I'm not young and beautiful?387Embed

# %%
# Import required libraries
import matplotlib.pyplot as plt
from nrclex import NRCLex
from wordcloud import WordCloud, STOPWORDS

# Emotion Analysis using NRCLex
emotion_scores = { 'fear': 0, 'anger': 0, 'anticip': 0, 'trust': 0, 'surprise': 0, 'positive': 0, 'negative': 0, 'sadness': 0, 'disgust': 0, 'joy': 0 }

def get_emotions(lyrics):
    # Splitting the lyrics into lines for emotion analysis
    lines = lyrics.split('\n')
    for line in lines:
        if line.strip():  # Check if the line is not empty
            text_object = NRCLex(line)
            for emotion in emotion_scores.keys():
                emotion_scores[emotion] += text_object.affect_frequencies.get(emotion, 0)

    # Normalizing the scores
    total_lines = len([line for line in lines if line.strip()])
    for emotion in emotion_scores:
        emotion_scores[emotion] /= total_lines

    # Visualization - Bar Chart
    emotions = list(emotion_scores.keys())
    scores = list(emotion_scores.values())
    print(emotions)
    print(scores)

get_emotions(lyrics)
# Out:
# ['fear', 'anger', 'anticip', 'trust', 'surprise', 'positive', 'negative', 'sadness', 'disgust', 'joy']
# [0.014227642276422762, 0.006097560975609756, 0.0, 0.038037166085946574, 0.03193960511033682, 0.18176538908246223, 0.044715447154471545, 0.03252032520325203, 0.0, 0.1289198606271777]
